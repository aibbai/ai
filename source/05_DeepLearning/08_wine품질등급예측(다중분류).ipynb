# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:95%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:22pt;}
.inner_cell{font-size:22pt;}
div.text_cell_render pre code {font-size:22pt; line-height:30px;}
div.output {font-size:20pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:22pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:20pt;padding:5px;}
table.dataframe{font-size:22px;}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:95%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:22pt;}
# .inner_cell{font-size:22pt;}
# div.text_cell_render pre code {font-size:22pt; line-height:30px;}
# div.output {font-size:20pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:22pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:20pt;padding:5px;}
# table.dataframe{font-size:22px;}
# </style>

# %% [markdown]
# # red wine 품질 등급 예측
# ```
# 1. 데이터 셋 확보 & 전처리
#     결측치 처리 -> 독립(입력)변수와 종속(타겟)변수를 분리 -> 독립변수의 스케일조정(StandardScaler)
#     -> 종속변수의 균형을 확인
#     -> 종속변수 원핫인코딩(pd.get_dummies) -> 훈련셋과 테스트셋분리(train_test_split)
# 2. 모델구성
# 3. 모델학습과정 설정(다중분류)
# 4. 모델학습(callbaccks, compute_class_weight를 이용)
# 5. 모델 평가(시각화, 평가, 교차표 - 테스트셋)
# 6. 모델 저장/예측
# ```
# ## 1. 데이터셋확보 및 전처리

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, save_model, load_model
from tensorflow.keras.layers import Input, Dense, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.regularizers import l2
from tensorflow.keras import metrics # metrics.Recall, metrics.Precision
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback, ReduceLROnPlateau
from matplotlib import pyplot as plt

# %%
redwine = pd.read_csv('data/winequality-red.csv', sep=';')
redwine.info() # 결측치 없음
# redwine = np.loadtext('data/winequality-red.csv', delimiter=';', skiprows=1) 넘파이배열로
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# 독립(입력)변수와 종속(타겟)변수를 분리
X_redwine = redwine.iloc[:, :-1].to_numpy() #.values와 유사. numpy로 변경
y_redwine = redwine.iloc[:, -1]
X_redwine.shape, y_redwine.shape
# Out:
# ((1599, 11), (1599,))

# %%
# 독립변수의 스케일 조정
scaler = StandardScaler()
# scaler.fit(X_redwine)
# scaled_X_redwine = scaler.transform(X_redwine)
scaled_X_redwine = scaler.fit_transform(X_redwine)

# %%
# 종속변수의 원핫인코딩
Y_redwine = pd.get_dummies(y_redwine).values
np.c_[y_redwine[2:4], Y_redwine[2:4]] # 원데이터와 원핫인코딩
# Out:
# array([[5, 0, 0, 1, 0, 0, 0],
#        [6, 0, 0, 0, 1, 0, 0]], dtype=int64)

# %%
# 종속변수의 균형을 확인
y_redwine.value_counts(normalize=True)
# Out:
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 4    0.033146
# 8    0.011257
# 3    0.006254
# Name: quality, dtype: float64

# %%
# 독립변수와 타겟변수
scaled_X_redwine.shape, Y_redwine.shape
# Out:
# ((1599, 11), (1599, 6))

# %%
# 훈련셋과 테스트셋 분리(층화추출) = 7 : 3
X_train, X_test, Y_train, Y_test = train_test_split(scaled_X_redwine, 
                                                    Y_redwine,
                                                    test_size=0.3,
                                                    #train_size=0.7,
                                                    stratify=Y_redwine, # 층화추출
                                                    random_state=12) # seed 값
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((1119, 11), (480, 11), (1119, 6), (480, 6))

# %% [markdown]
# # 2. 모델구성
# - 입력 11 -> 64 -> 50 -> 30 -> 출력 6
# - He초기화 : 층이 깊을 때 활성화함수를 relu사용시

# %%
model = Sequential(name='Sequential')
model.add(Input(11))
model.add(Dense(units=64, activation='relu', kernel_initializer=HeNormal(seed=42)))
model.add(Dense(units=50, activation='relu', kernel_initializer='he_normal'))
model.add(Dropout(0.1))
model.add(Dense(units=30, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(units=6, activation='softmax'))
model.summary()
# Out:
# Model: "Sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                768
#
#  dense_1 (Dense)             (None, 50)                3250
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense_2 (Dense)             (None, 30)                1530
#
#  dense_3 (Dense)             (None, 6)                 186
#
# =================================================================
# Total params: 5,734
# Trainable params: 5,734
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. 학습과정 설정

# %%
model.compile(loss='categorical_crossentropy', # sparse_categorical_crossentropy
             optimizer='adam',
             metrics=['accuracy',
                      metrics.Recall(name='recall'),
                      metrics.Precision(name='precision')])

# %% [markdown]
# # 4. 학습시키기
# - callbacks 이용

# %%
# %%time
earlyStopping = EarlyStopping(monitor='val_loss', patience=10)
hist = model.fit(X_train, Y_train,
                 validation_split=0.2, # 학습셋의 20%를 검증셋으로
                 # class_weight=class_weight_dict,
                callbacks=[earlyStopping],
                epochs=200,
                verbose=2)
# Out:
# Epoch 1/200
# 28/28 - 1s - loss: 1.7555 - accuracy: 0.3173 - recall: 0.0838 - precision: 0.4011 - val_loss: 1.3361 - val_accuracy: 0.4777 - val_recall: 0.1920 - val_precision: 0.5584 - 1s/epoch - 51ms/step
# Epoch 2/200
# 28/28 - 0s - loss: 1.2337 - accuracy: 0.5374 - recall: 0.2737 - precision: 0.5833 - val_loss: 1.1642 - val_accuracy: 0.4911 - val_recall: 0.3527 - val_precision: 0.5766 - 76ms/epoch - 3ms/step
# Epoch 3/200
# 28/28 - 0s - loss: 1.1045 - accuracy: 0.5810 - recall: 0.3832 - precision: 0.5893 - val_loss: 1.1335 - val_accuracy: 0.5045 - val_recall: 0.3884 - val_precision: 0.5878 - 81ms/epoch - 3ms/step
# Epoch 4/200
# 28/28 - 0s - loss: 1.0418 - accuracy: 0.5732 - recall: 0.3944 - precision: 0.6076 - val_loss: 1.1179 - val_accuracy: 0.5089 - val_recall: 0.3929 - val_precision: 0.5535 - 83ms/epoch - 3ms/step
# Epoch 5/200
# 28/28 - 0s - loss: 1.0307 - accuracy: 0.5799 - recall: 0.4268 - precision: 0.6132 - val_loss: 1.0959 - val_accuracy: 0.5223 - val_recall: 0.3929 - val_precision: 0.5677 - 70ms/epoch - 3ms/step
# Epoch 6/200
# 28/28 - 0s - loss: 0.9724 - accuracy: 0.6212 - recall: 0.4626 - precision: 0.6469 - val_loss: 1.0850 - val_accuracy: 0.5312 - val_recall: 0.4286 - val_precision: 0.5517 - 82ms/epoch - 3ms/step
# Epoch 7/200
# 28/28 - 0s - loss: 0.9486 - accuracy: 0.6078 - recall: 0.4715 - precision: 0.6462 - val_loss: 1.0621 - val_accuracy: 0.5446 - val_recall: 0.4509 - val_precision: 0.5674 - 77ms/epoch - 3ms/step
# Epoch 8/200
# 28/28 - 0s - loss: 0.9369 - accuracy: 0.6156 - recall: 0.5229 - precision: 0.6536 - val_loss: 1.0530 - val_accuracy: 0.5625 - val_recall: 0.4598 - val_precision: 0.5852 - 75ms/epoch - 3ms/step
# Epoch 9/200
# 28/28 - 0s - loss: 0.9092 - accuracy: 0.6246 - recall: 0.5128 - precision: 0.6604 - val_loss: 1.0364 - val_accuracy: 0.5536 - val_recall: 0.4330 - val_precision: 0.5843 - 88ms/epoch - 3ms/step
# Epoch 10/200
# 28/28 - 0s - loss: 0.9056 - accuracy: 0.6212 - recall: 0.5006 - precision: 0.6647 - val_loss: 1.0495 - val_accuracy: 0.5402 - val_recall: 0.4420 - val_precision: 0.5562 - 91ms/epoch - 3ms/step
# Epoch 11/200
# 28/28 - 0s - loss: 0.8770 - accuracy: 0.6346 - recall: 0.5318 - precision: 0.6819 - val_loss: 1.0328 - val_accuracy: 0.5804 - val_recall: 0.4732 - val_precision: 0.5699 - 82ms/epoch - 3ms/step
# Epoch 12/200
# 28/28 - 0s - loss: 0.8662 - accuracy: 0.6570 - recall: 0.5330 - precision: 0.7025 - val_loss: 1.0397 - val_accuracy: 0.5848 - val_recall: 0.4955 - val_precision: 0.5842 - 83ms/epoch - 3ms/step
# Epoch 13/200
# 28/28 - 0s - loss: 0.8541 - accuracy: 0.6525 - recall: 0.5698 - precision: 0.6967 - val_loss: 1.0298 - val_accuracy: 0.5804 - val_recall: 0.5045 - val_precision: 0.5795 - 93ms/epoch - 3ms/step
# Epoch 14/200
# 28/28 - 0s - loss: 0.8325 - accuracy: 0.6480 - recall: 0.5609 - precision: 0.6896 - val_loss: 1.0307 - val_accuracy: 0.5714 - val_recall: 0.5134 - val_precision: 0.5867 - 90ms/epoch - 3ms/step
# Epoch 15/200
# 28/28 - 0s - loss: 0.8325 - accuracy: 0.6436 - recall: 0.5620 - precision: 0.6938 - val_loss: 1.0324 - val_accuracy: 0.5670 - val_recall: 0.4911 - val_precision: 0.5820 - 73ms/epoch - 3ms/step
# Epoch 16/200
# 28/28 - 0s - loss: 0.8211 - accuracy: 0.6492 - recall: 0.5676 - precision: 0.6959 - val_loss: 1.0514 - val_accuracy: 0.5536 - val_recall: 0.4732 - val_precision: 0.5550 - 82ms/epoch - 3ms/step
# Epoch 17/200
# 28/28 - 0s - loss: 0.8266 - accuracy: 0.6536 - recall: 0.5620 - precision: 0.6900 - val_loss: 1.0356 - val_accuracy: 0.5714 - val_recall: 0.5179 - val_precision: 0.5979 - 84ms/epoch - 3ms/step
# Epoch 18/200
# 28/28 - 0s - loss: 0.8092 - accuracy: 0.6536 - recall: 0.5754 - precision: 0.6913 - val_loss: 1.0564 - val_accuracy: 0.5804 - val_recall: 0.5134 - val_precision: 0.5838 - 83ms/epoch - 3ms/step
# Epoch 19/200
# 28/28 - 0s - loss: 0.8066 - accuracy: 0.6570 - recall: 0.5933 - precision: 0.6978 - val_loss: 1.0250 - val_accuracy: 0.5714 - val_recall: 0.4955 - val_precision: 0.5812 - 81ms/epoch - 3ms/step
# Epoch 20/200
# 28/28 - 0s - loss: 0.7784 - accuracy: 0.6704 - recall: 0.5933 - precision: 0.7166 - val_loss: 1.0532 - val_accuracy: 0.5670 - val_recall: 0.4955 - val_precision: 0.5663 - 73ms/epoch - 3ms/step
# Epoch 21/200
# 28/28 - 0s - loss: 0.7774 - accuracy: 0.6749 - recall: 0.6045 - precision: 0.7252 - val_loss: 1.0396 - val_accuracy: 0.5580 - val_recall: 0.4955 - val_precision: 0.5692 - 98ms/epoch - 3ms/step
# Epoch 22/200
# 28/28 - 0s - loss: 0.7797 - accuracy: 0.6726 - recall: 0.5922 - precision: 0.7250 - val_loss: 1.0248 - val_accuracy: 0.5536 - val_recall: 0.4821 - val_precision: 0.5684 - 111ms/epoch - 4ms/step
# Epoch 23/200
# 28/28 - 0s - loss: 0.7554 - accuracy: 0.6749 - recall: 0.6045 - precision: 0.7166 - val_loss: 1.0484 - val_accuracy: 0.5714 - val_recall: 0.5179 - val_precision: 0.5859 - 100ms/epoch - 4ms/step
# Epoch 24/200
# 28/28 - 0s - loss: 0.7598 - accuracy: 0.6804 - recall: 0.6022 - precision: 0.7196 - val_loss: 1.0463 - val_accuracy: 0.5670 - val_recall: 0.5089 - val_precision: 0.5846 - 96ms/epoch - 3ms/step
# Epoch 25/200
# 28/28 - 0s - loss: 0.7502 - accuracy: 0.6804 - recall: 0.6101 - precision: 0.7203 - val_loss: 1.0473 - val_accuracy: 0.5491 - val_recall: 0.5000 - val_precision: 0.5744 - 122ms/epoch - 4ms/step
# Epoch 26/200
# 28/28 - 0s - loss: 0.7531 - accuracy: 0.6760 - recall: 0.6089 - precision: 0.7199 - val_loss: 1.0310 - val_accuracy: 0.5759 - val_recall: 0.5089 - val_precision: 0.5938 - 85ms/epoch - 3ms/step
# Epoch 27/200
# 28/28 - 0s - loss: 0.7259 - accuracy: 0.6972 - recall: 0.6268 - precision: 0.7382 - val_loss: 1.0525 - val_accuracy: 0.5625 - val_recall: 0.5045 - val_precision: 0.5765 - 99ms/epoch - 4ms/step
# Epoch 28/200
# 28/28 - 0s - loss: 0.7383 - accuracy: 0.6972 - recall: 0.6302 - precision: 0.7277 - val_loss: 1.0306 - val_accuracy: 0.5625 - val_recall: 0.4911 - val_precision: 0.5759 - 98ms/epoch - 3ms/step
# Epoch 29/200
# 28/28 - 0s - loss: 0.7215 - accuracy: 0.7073 - recall: 0.6358 - precision: 0.7467 - val_loss: 1.0503 - val_accuracy: 0.5759 - val_recall: 0.5089 - val_precision: 0.5758 - 88ms/epoch - 3ms/step
# Epoch 30/200
# 28/28 - 0s - loss: 0.7107 - accuracy: 0.7140 - recall: 0.6436 - precision: 0.7451 - val_loss: 1.0756 - val_accuracy: 0.5580 - val_recall: 0.4955 - val_precision: 0.5722 - 84ms/epoch - 3ms/step
# Epoch 31/200
# 28/28 - 0s - loss: 0.7037 - accuracy: 0.7006 - recall: 0.6480 - precision: 0.7360 - val_loss: 1.0465 - val_accuracy: 0.5670 - val_recall: 0.5000 - val_precision: 0.5773 - 96ms/epoch - 3ms/step
# Epoch 32/200
# 28/28 - 0s - loss: 0.7068 - accuracy: 0.7006 - recall: 0.6380 - precision: 0.7358 - val_loss: 1.0519 - val_accuracy: 0.5402 - val_recall: 0.4955 - val_precision: 0.5578 - 85ms/epoch - 3ms/step
# CPU times: total: 6.03 s
# Wall time: 4.5 s

# %% [markdown]
# # 5. 모델 평가
# - 시각화, 평가, 교차표

# %%
# 학습과정 살펴보기(시각화)
fig, loss_ax = plt.subplots(figsize=(15,6))
loss_ax.plot(hist.history['loss'], 'y', label='train_loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val_loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train_accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val_accuracy')
acc_ax.plot(hist.history['val_recall'], 'k', label='val_accuracy')
acc_ax.plot(hist.history['val_precision'], 'k', label='val_accuracy')

acc_ax.set_ylabel('accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(bbox_to_anchor=(0.97,0.75))
acc_ax.legend(loc='center right')
plt.show()

# %%
# 평가
loss, acc, recall, precision = model.evaluate(X_test, Y_test, verbose=0)
print('정확도 :', acc)
print('재현율 :', recall)
print('정밀도 :', precision)
# Out:
# 정확도 : 0.6333333253860474
# 재현율 : 0.5687500238418579
# 정밀도 : 0.6594203114509583

# %%
# 교차표를 위한 y_hat
y_hat = model.predict(X_test).argmax(axis=1) + 3 # 예측값
y = Y_test.argmax(axis=1) + 3 # 실제값
pd.crosstab(y, y_hat, rownames=['실제'], colnames=['예측'])
# Out:
# 15/15 [==============================] - 0s 2ms/step
# 예측    5    6   7
# 실제
# 3     3    0   0
# 4     9    6   1
# 5   143   57   4
# 6    43  135  14
# 7     2   32  26
# 8     0    2   3

# %% [markdown]
# # 6. 모델 사용

# %%
X_redwine[0]
# Out:
# array([ 7.4   ,  0.7   ,  0.    ,  1.9   ,  0.076 , 11.    , 34.    ,
#         0.9978,  3.51  ,  0.56  ,  9.4   ])

# %%
data = [[  7.4, 0.7, 0., 1.9, 0.076, 11., 34., 0.9978, 3.51, 0.56, 9.4  ]]
input_data = scaler.transform(data)
model.predict(input_data).argmax(axis=1)+3
# Out:
# 1/1 [==============================] - 0s 130ms/step
# array([5], dtype=int64)
