# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:95%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:22pt;}
.inner_cell{font-size:22pt;}
div.text_cell_render pre code {font-size:22pt; line-height:30px;}
div.output {font-size:20pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:22pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:20pt;padding:5px;}
table.dataframe{font-size:22px;}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:95%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:22pt;}
# .inner_cell{font-size:22pt;}
# div.text_cell_render pre code {font-size:22pt; line-height:30px;}
# div.output {font-size:20pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:22pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:20pt;padding:5px;}
# table.dataframe{font-size:22px;}
# </style>

# %%
import numpy as np
import pandas as pd
import seaborn as sns # iris(데이터프레임)가져오기
from sklearn import datasets # iris(X와 y가 분리되서 numpy) 가져오기
from sklearn.preprocessing import LabelEncoder # 라벨 인코더
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential, save_model, load_model
from tensorflow.keras.layers import Input, Dense, LeakyReLU, Dropout

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from matplotlib import pyplot as plt

# %% [markdown]
# ```
# - 데이터셋 생성 및 전처리
#     X, y(라벨인코딩)분리 -> train_test_split 분리(8:2)
# - 모델 구성(입력4, 출력3, layer : 4->64->128->50->30->3)
# - 학습과정 설정 (loss='sparse_categorical_crossentropy')
# - 학습
# - 모델평가(가장 최선의 모델을 get)
# - 모델 사용(저장/예측)
# ```
# # 1. 기본적인 DNN
# ## 1. 데이터 셋 생성 및 전처리

# %%
# iris가져오기 방법 1
iris = sns.load_dataset('iris')
iris['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
iris_X = iris.iloc[:, :-1].values
labelEncoder = LabelEncoder()
iris_y = labelEncoder.fit_transform(iris.iloc[:, -1]) # 0:setosa/1:versicolor/2:virginica
iris_X.shape, iris_y.shape
# Out:
# ((150, 4), (150,))

# %%
# iris가져오기 방법 2
iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target
print(iris.target_names)
iris_X.shape, iris_y.shape
# Out:
# ['setosa' 'versicolor' 'virginica']
# ((150, 4), (150,))

# %%
# 학습셋과 테스트셋 분리
train_X, test_X, train_y, test_y = train_test_split(iris_X, iris_y,
                                                   test_size=0.2,
                                                   stratify=iris_y # 층화추출
                                                   )
np.c_[pd.Series(iris_y).value_counts(normalize=True),
      pd.Series(train_y).value_counts(normalize=True),
      pd.Series(test_y).value_counts(normalize=True)]
# Out:
# array([[0.33333333, 0.33333333, 0.33333333],
#        [0.33333333, 0.33333333, 0.33333333],
#        [0.33333333, 0.33333333, 0.33333333]])

# %%
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((120, 4), (120,), (30, 4), (30,))

# %% [markdown]
# ## 2. 모델 구성 및 학습
# - 4->64->128->50->30->3
# - He초기화, 다양한 activation, 배치정규화, L2정규화, Dropout

# %%
model = Sequential([
    Input(4),
    Dense(units=64, activation='relu'),
    Dense(units=128, activation='elu'),
    Dense(units=50, activation='relu'),
    Dense(units=30, activation='relu'),
    Dense(units=3, activation='softmax'),
], 'sequential')
# model = Sequential(name='sequential')
# model.add(Input(4))
# model.add(Dense(units=64, activation='relu'))
# model.add(Dense(units=128, activation='relu'))
# model.add(Dense(units=50, activation='relu'))
# model.add(Dense(units=30, activation='relu'))
# model.add(Dense(units=3, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_25 (Dense)            (None, 64)                320
#
#  dense_26 (Dense)            (None, 128)               8320
#
#  dense_27 (Dense)            (None, 50)                6450
#
#  dense_28 (Dense)            (None, 30)                1530
#
#  dense_29 (Dense)            (None, 3)                 93
#
# =================================================================
# Total params: 16,713
# Trainable params: 16,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
model.compile(loss='sparse_categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
earlystopping = EarlyStopping(patience=50) # monitor='val_loss'가 기본값
model_save_folder = 'model/'
import os
if not os.path.exists(model_save_folder):
    os.mkdir(model_save_folder)
file = model_save_folder + 'iris-{epoch:03d}-loss{val_loss:.4f}-acc{val_accuracy:.4f}.h5'
checkpoint = ModelCheckpoint(monitor='val_loss',
                            filepath=file, # 모델 저장 파일
                            save_best_only=True, # 모니터 지표가 개선된 경우만 모델 저장
                            verbose=1) # 저장 여부 로그 출력
hist = model.fit(train_X, train_y,
                epochs=200,
                validation_split=0.1,
                callbacks=[earlystopping, checkpoint],
                verbose=1)
# Out:
# Epoch 1/200
# 1/4 [======>.......................] - ETA: 1s - loss: 1.0816 - accuracy: 0.5625
# Epoch 1: val_loss improved from inf to 0.88639, saving model to model\iris-001-loss0.8864-acc0.7500.h5
# 4/4 [==============================] - 1s 86ms/step - loss: 1.0677 - accuracy: 0.6019 - val_loss: 0.8864 - val_accuracy: 0.7500
# Epoch 2/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.8835 - accuracy: 0.7188
# Epoch 2: val_loss improved from 0.88639 to 0.74542, saving model to model\iris-002-loss0.7454-acc0.7500.h5
# 4/4 [==============================] - 0s 22ms/step - loss: 0.8789 - accuracy: 0.6574 - val_loss: 0.7454 - val_accuracy: 0.7500
# Epoch 3/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7586 - accuracy: 0.7500
# Epoch 3: val_loss improved from 0.74542 to 0.63729, saving model to model\iris-003-loss0.6373-acc0.8333.h5
# 4/4 [==============================] - 0s 21ms/step - loss: 0.7781 - accuracy: 0.7037 - val_loss: 0.6373 - val_accuracy: 0.8333
# Epoch 4/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7134 - accuracy: 0.8125
# Epoch 4: val_loss improved from 0.63729 to 0.56463, saving model to model\iris-004-loss0.5646-acc0.7500.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 0.6790 - accuracy: 0.8519 - val_loss: 0.5646 - val_accuracy: 0.7500
# Epoch 5/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6458 - accuracy: 0.6875
# Epoch 5: val_loss improved from 0.56463 to 0.45666, saving model to model\iris-005-loss0.4567-acc0.7500.h5
# 4/4 [==============================] - 0s 26ms/step - loss: 0.5980 - accuracy: 0.7315 - val_loss: 0.4567 - val_accuracy: 0.7500
# Epoch 6/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5461 - accuracy: 0.7812
# Epoch 6: val_loss improved from 0.45666 to 0.36691, saving model to model\iris-006-loss0.3669-acc1.0000.h5
# 4/4 [==============================] - 0s 23ms/step - loss: 0.5143 - accuracy: 0.8333 - val_loss: 0.3669 - val_accuracy: 1.0000
# Epoch 7/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5111 - accuracy: 0.9375
# Epoch 7: val_loss improved from 0.36691 to 0.30064, saving model to model\iris-007-loss0.3006-acc1.0000.h5
# 4/4 [==============================] - 0s 30ms/step - loss: 0.4412 - accuracy: 0.9444 - val_loss: 0.3006 - val_accuracy: 1.0000
# Epoch 8/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3765 - accuracy: 0.9062
# Epoch 8: val_loss improved from 0.30064 to 0.25913, saving model to model\iris-008-loss0.2591-acc1.0000.h5
# 4/4 [==============================] - 0s 31ms/step - loss: 0.3734 - accuracy: 0.9444 - val_loss: 0.2591 - val_accuracy: 1.0000
# Epoch 9/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3547 - accuracy: 0.8750
# Epoch 9: val_loss improved from 0.25913 to 0.21672, saving model to model\iris-009-loss0.2167-acc1.0000.h5
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3264 - accuracy: 0.9259 - val_loss: 0.2167 - val_accuracy: 1.0000
# Epoch 10/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3196 - accuracy: 0.9375
# Epoch 10: val_loss improved from 0.21672 to 0.18029, saving model to model\iris-010-loss0.1803-acc1.0000.h5
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2839 - accuracy: 0.9352 - val_loss: 0.1803 - val_accuracy: 1.0000
# Epoch 11/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2715 - accuracy: 0.9688
# Epoch 11: val_loss improved from 0.18029 to 0.15585, saving model to model\iris-011-loss0.1558-acc1.0000.h5
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2521 - accuracy: 0.9630 - val_loss: 0.1558 - val_accuracy: 1.0000
# Epoch 12/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1990 - accuracy: 1.0000
# Epoch 12: val_loss improved from 0.15585 to 0.14014, saving model to model\iris-012-loss0.1401-acc1.0000.h5
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2243 - accuracy: 0.9722 - val_loss: 0.1401 - val_accuracy: 1.0000
# Epoch 13/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2214 - accuracy: 1.0000
# Epoch 13: val_loss improved from 0.14014 to 0.12868, saving model to model\iris-013-loss0.1287-acc1.0000.h5
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2106 - accuracy: 0.9444 - val_loss: 0.1287 - val_accuracy: 1.0000
# Epoch 14/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1636 - accuracy: 0.9688
# Epoch 14: val_loss improved from 0.12868 to 0.12695, saving model to model\iris-014-loss0.1269-acc0.9167.h5
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1802 - accuracy: 0.9630 - val_loss: 0.1269 - val_accuracy: 0.9167
# Epoch 15/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2280 - accuracy: 0.8750
# Epoch 15: val_loss improved from 0.12695 to 0.10257, saving model to model\iris-015-loss0.1026-acc1.0000.h5
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1784 - accuracy: 0.9352 - val_loss: 0.1026 - val_accuracy: 1.0000
# Epoch 16/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0904 - accuracy: 1.0000
# Epoch 16: val_loss improved from 0.10257 to 0.08849, saving model to model\iris-016-loss0.0885-acc1.0000.h5
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1499 - accuracy: 0.9815 - val_loss: 0.0885 - val_accuracy: 1.0000
# Epoch 17/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1454 - accuracy: 0.9688
# Epoch 17: val_loss improved from 0.08849 to 0.08479, saving model to model\iris-017-loss0.0848-acc1.0000.h5
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1411 - accuracy: 0.9630 - val_loss: 0.0848 - val_accuracy: 1.0000
# Epoch 18/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1267 - accuracy: 0.9688
# Epoch 18: val_loss improved from 0.08479 to 0.07818, saving model to model\iris-018-loss0.0782-acc1.0000.h5
# 4/4 [==============================] - 0s 25ms/step - loss: 0.1470 - accuracy: 0.9352 - val_loss: 0.0782 - val_accuracy: 1.0000
# Epoch 19/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1050 - accuracy: 0.9688
# Epoch 19: val_loss improved from 0.07818 to 0.06776, saving model to model\iris-019-loss0.0678-acc1.0000.h5
# 4/4 [==============================] - 0s 24ms/step - loss: 0.1211 - accuracy: 0.9722 - val_loss: 0.0678 - val_accuracy: 1.0000
# Epoch 20/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2195 - accuracy: 0.9375
# Epoch 20: val_loss improved from 0.06776 to 0.06334, saving model to model\iris-020-loss0.0633-acc1.0000.h5
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1257 - accuracy: 0.9630 - val_loss: 0.0633 - val_accuracy: 1.0000
# Epoch 21/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1749 - accuracy: 0.9375
# Epoch 21: val_loss did not improve from 0.06334
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1266 - accuracy: 0.9537 - val_loss: 0.0699 - val_accuracy: 1.0000
# Epoch 22/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0442 - accuracy: 1.0000
# Epoch 22: val_loss improved from 0.06334 to 0.05421, saving model to model\iris-022-loss0.0542-acc1.0000.h5
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1084 - accuracy: 0.9815 - val_loss: 0.0542 - val_accuracy: 1.0000
# Epoch 23/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0999 - accuracy: 0.9375
# Epoch 23: val_loss improved from 0.05421 to 0.05086, saving model to model\iris-023-loss0.0509-acc1.0000.h5
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1364 - accuracy: 0.9259 - val_loss: 0.0509 - val_accuracy: 1.0000
# Epoch 24/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0702 - accuracy: 1.0000
# Epoch 24: val_loss did not improve from 0.05086
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1635 - accuracy: 0.9444 - val_loss: 0.0657 - val_accuracy: 1.0000
# Epoch 25/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1315 - accuracy: 0.9375
# Epoch 25: val_loss did not improve from 0.05086
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1101 - accuracy: 0.9722 - val_loss: 0.1326 - val_accuracy: 0.9167
# Epoch 26/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2343 - accuracy: 0.8438
# Epoch 26: val_loss improved from 0.05086 to 0.04770, saving model to model\iris-026-loss0.0477-acc1.0000.h5
# 4/4 [==============================] - 0s 24ms/step - loss: 0.1360 - accuracy: 0.9259 - val_loss: 0.0477 - val_accuracy: 1.0000
# Epoch 27/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0870 - accuracy: 0.9688
# Epoch 27: val_loss improved from 0.04770 to 0.03932, saving model to model\iris-027-loss0.0393-acc1.0000.h5
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0938 - accuracy: 0.9722 - val_loss: 0.0393 - val_accuracy: 1.0000
# Epoch 28/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1379 - accuracy: 0.9375
# Epoch 28: val_loss did not improve from 0.03932
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1019 - accuracy: 0.9630 - val_loss: 0.0468 - val_accuracy: 1.0000
# Epoch 29/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0524 - accuracy: 0.9688
# Epoch 29: val_loss did not improve from 0.03932
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0992 - accuracy: 0.9444 - val_loss: 0.0723 - val_accuracy: 0.9167
# Epoch 30/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0892 - accuracy: 0.9375
# Epoch 30: val_loss did not improve from 0.03932
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0989 - accuracy: 0.9352 - val_loss: 0.0469 - val_accuracy: 1.0000
# Epoch 31/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0732 - accuracy: 1.0000
# Epoch 31: val_loss did not improve from 0.03932
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0928 - accuracy: 0.9815 - val_loss: 0.0563 - val_accuracy: 1.0000
# Epoch 32/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0605 - accuracy: 0.9688
# Epoch 32: val_loss did not improve from 0.03932
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0950 - accuracy: 0.9722 - val_loss: 0.0415 - val_accuracy: 1.0000
# Epoch 33/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0675 - accuracy: 0.9688
# Epoch 33: val_loss did not improve from 0.03932
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0923 - accuracy: 0.9722 - val_loss: 0.0516 - val_accuracy: 1.0000
# Epoch 34/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0216 - accuracy: 1.0000
# Epoch 34: val_loss did not improve from 0.03932
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1010 - accuracy: 0.9352 - val_loss: 0.0655 - val_accuracy: 1.0000
# Epoch 35/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0824 - accuracy: 0.9688
# Epoch 35: val_loss improved from 0.03932 to 0.03372, saving model to model\iris-035-loss0.0337-acc1.0000.h5
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0896 - accuracy: 0.9815 - val_loss: 0.0337 - val_accuracy: 1.0000
# Epoch 36/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1219 - accuracy: 0.9688
# Epoch 36: val_loss improved from 0.03372 to 0.03299, saving model to model\iris-036-loss0.0330-acc1.0000.h5
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0956 - accuracy: 0.9630 - val_loss: 0.0330 - val_accuracy: 1.0000
# Epoch 37/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0953 - accuracy: 1.0000
# Epoch 37: val_loss improved from 0.03299 to 0.03203, saving model to model\iris-037-loss0.0320-acc1.0000.h5
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0960 - accuracy: 0.9722 - val_loss: 0.0320 - val_accuracy: 1.0000
# Epoch 38/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0544 - accuracy: 1.0000
# Epoch 38: val_loss did not improve from 0.03203
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0841 - accuracy: 0.9815 - val_loss: 0.0697 - val_accuracy: 0.9167
# Epoch 39/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1007 - accuracy: 0.9375
# Epoch 39: val_loss improved from 0.03203 to 0.02714, saving model to model\iris-039-loss0.0271-acc1.0000.h5
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0833 - accuracy: 0.9722 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 40/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0281 - accuracy: 1.0000
# Epoch 40: val_loss did not improve from 0.02714
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1299 - accuracy: 0.9444 - val_loss: 0.0311 - val_accuracy: 1.0000
# Epoch 41/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0742 - accuracy: 0.9375
# Epoch 41: val_loss did not improve from 0.02714
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1231 - accuracy: 0.9167 - val_loss: 0.0712 - val_accuracy: 0.9167
# Epoch 42/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0705 - accuracy: 0.9375
# Epoch 42: val_loss did not improve from 0.02714
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0983 - accuracy: 0.9444 - val_loss: 0.0275 - val_accuracy: 1.0000
# Epoch 43/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0326 - accuracy: 1.0000
# Epoch 43: val_loss did not improve from 0.02714
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0984 - accuracy: 0.9630 - val_loss: 0.0517 - val_accuracy: 1.0000
# Epoch 44/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1323 - accuracy: 0.9375
# Epoch 44: val_loss did not improve from 0.02714
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0886 - accuracy: 0.9630 - val_loss: 0.0589 - val_accuracy: 1.0000
# Epoch 45/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0343 - accuracy: 1.0000
# Epoch 45: val_loss improved from 0.02714 to 0.02494, saving model to model\iris-045-loss0.0249-acc1.0000.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0748 - accuracy: 0.9815 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 46/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0330 - accuracy: 1.0000
# Epoch 46: val_loss did not improve from 0.02494
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1192 - accuracy: 0.9537 - val_loss: 0.0259 - val_accuracy: 1.0000
# Epoch 47/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0341 - accuracy: 1.0000
# Epoch 47: val_loss did not improve from 0.02494
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0908 - accuracy: 0.9537 - val_loss: 0.0853 - val_accuracy: 0.9167
# Epoch 48/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1052 - accuracy: 0.9375
# Epoch 48: val_loss improved from 0.02494 to 0.02397, saving model to model\iris-048-loss0.0240-acc1.0000.h5
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0859 - accuracy: 0.9630 - val_loss: 0.0240 - val_accuracy: 1.0000
# Epoch 49/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0208 - accuracy: 1.0000
# Epoch 49: val_loss did not improve from 0.02397
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1018 - accuracy: 0.9537 - val_loss: 0.0391 - val_accuracy: 1.0000
# Epoch 50/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0359 - accuracy: 0.9688
# Epoch 50: val_loss did not improve from 0.02397
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0906 - accuracy: 0.9352 - val_loss: 0.0986 - val_accuracy: 0.9167
# Epoch 51/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0440 - accuracy: 0.9688
# Epoch 51: val_loss did not improve from 0.02397
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0989 - accuracy: 0.9444 - val_loss: 0.0260 - val_accuracy: 1.0000
# Epoch 52/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0637 - accuracy: 0.9688
# Epoch 52: val_loss improved from 0.02397 to 0.02124, saving model to model\iris-052-loss0.0212-acc1.0000.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0866 - accuracy: 0.9722 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 53/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0425 - accuracy: 0.9688
# Epoch 53: val_loss did not improve from 0.02124
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0873 - accuracy: 0.9630 - val_loss: 0.0504 - val_accuracy: 1.0000
# Epoch 54/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0520 - accuracy: 1.0000
# Epoch 54: val_loss did not improve from 0.02124
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0766 - accuracy: 0.9907 - val_loss: 0.0229 - val_accuracy: 1.0000
# Epoch 55/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1621 - accuracy: 0.9375
# Epoch 55: val_loss did not improve from 0.02124
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0806 - accuracy: 0.9722 - val_loss: 0.0281 - val_accuracy: 1.0000
# Epoch 56/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0545 - accuracy: 0.9688
# Epoch 56: val_loss did not improve from 0.02124
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0771 - accuracy: 0.9722 - val_loss: 0.0341 - val_accuracy: 1.0000
# Epoch 57/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0750 - accuracy: 0.9688
# Epoch 57: val_loss did not improve from 0.02124
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0782 - accuracy: 0.9815 - val_loss: 0.0449 - val_accuracy: 1.0000
# Epoch 58/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0491 - accuracy: 1.0000
# Epoch 58: val_loss did not improve from 0.02124
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0782 - accuracy: 0.9722 - val_loss: 0.0262 - val_accuracy: 1.0000
# Epoch 59/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0170 - accuracy: 1.0000
# Epoch 59: val_loss did not improve from 0.02124
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0747 - accuracy: 0.9722 - val_loss: 0.0355 - val_accuracy: 1.0000
# Epoch 60/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0231 - accuracy: 1.0000
# Epoch 60: val_loss did not improve from 0.02124
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0755 - accuracy: 0.9722 - val_loss: 0.0219 - val_accuracy: 1.0000
# Epoch 61/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0499 - accuracy: 0.9688
# Epoch 61: val_loss did not improve from 0.02124
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0796 - accuracy: 0.9722 - val_loss: 0.0264 - val_accuracy: 1.0000
# Epoch 62/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1225 - accuracy: 0.9688
# Epoch 62: val_loss did not improve from 0.02124
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0819 - accuracy: 0.9630 - val_loss: 0.0486 - val_accuracy: 1.0000
# Epoch 63/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0334 - accuracy: 0.9688
# Epoch 63: val_loss improved from 0.02124 to 0.01852, saving model to model\iris-063-loss0.0185-acc1.0000.h5
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0747 - accuracy: 0.9630 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 64/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0446 - accuracy: 1.0000
# Epoch 64: val_loss did not improve from 0.01852
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0826 - accuracy: 0.9722 - val_loss: 0.0300 - val_accuracy: 1.0000
# Epoch 65/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0684 - accuracy: 0.9688
# Epoch 65: val_loss did not improve from 0.01852
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0748 - accuracy: 0.9630 - val_loss: 0.0428 - val_accuracy: 1.0000
# Epoch 66/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1667 - accuracy: 0.9375
# Epoch 66: val_loss did not improve from 0.01852
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0746 - accuracy: 0.9815 - val_loss: 0.0337 - val_accuracy: 1.0000
# Epoch 67/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0352 - accuracy: 1.0000
# Epoch 67: val_loss did not improve from 0.01852
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0736 - accuracy: 0.9722 - val_loss: 0.0263 - val_accuracy: 1.0000
# Epoch 68/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1055 - accuracy: 0.9688
# Epoch 68: val_loss did not improve from 0.01852
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0897 - accuracy: 0.9444 - val_loss: 0.0291 - val_accuracy: 1.0000
# Epoch 69/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0358 - accuracy: 1.0000
# Epoch 69: val_loss did not improve from 0.01852
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0712 - accuracy: 0.9815 - val_loss: 0.0213 - val_accuracy: 1.0000
# Epoch 70/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0484 - accuracy: 0.9688
# Epoch 70: val_loss did not improve from 0.01852
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0716 - accuracy: 0.9722 - val_loss: 0.0279 - val_accuracy: 1.0000
# Epoch 71/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1184 - accuracy: 0.9688
# Epoch 71: val_loss did not improve from 0.01852
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0779 - accuracy: 0.9722 - val_loss: 0.0303 - val_accuracy: 1.0000
# Epoch 72/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0459 - accuracy: 1.0000
# Epoch 72: val_loss did not improve from 0.01852
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0695 - accuracy: 0.9815 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 73/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0692 - accuracy: 0.9688
# Epoch 73: val_loss improved from 0.01852 to 0.01701, saving model to model\iris-073-loss0.0170-acc1.0000.h5
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0898 - accuracy: 0.9630 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 74/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0225 - accuracy: 1.0000
# Epoch 74: val_loss did not improve from 0.01701
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0642 - accuracy: 0.9815 - val_loss: 0.0743 - val_accuracy: 0.9167
# Epoch 75/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1150 - accuracy: 0.9062
# Epoch 75: val_loss did not improve from 0.01701
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0850 - accuracy: 0.9537 - val_loss: 0.0274 - val_accuracy: 1.0000
# Epoch 76/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0510 - accuracy: 0.9688
# Epoch 76: val_loss did not improve from 0.01701
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0689 - accuracy: 0.9815 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 77/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1268 - accuracy: 0.9688
# Epoch 77: val_loss did not improve from 0.01701
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0724 - accuracy: 0.9815 - val_loss: 0.0215 - val_accuracy: 1.0000
# Epoch 78/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1021 - accuracy: 0.9688
# Epoch 78: val_loss did not improve from 0.01701
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0737 - accuracy: 0.9722 - val_loss: 0.0189 - val_accuracy: 1.0000
# Epoch 79/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1325 - accuracy: 0.9688
# Epoch 79: val_loss did not improve from 0.01701
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0749 - accuracy: 0.9722 - val_loss: 0.0540 - val_accuracy: 1.0000
# Epoch 80/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0221 - accuracy: 1.0000
# Epoch 80: val_loss improved from 0.01701 to 0.01315, saving model to model\iris-080-loss0.0132-acc1.0000.h5
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0792 - accuracy: 0.9537 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 81/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1238 - accuracy: 0.9688
# Epoch 81: val_loss did not improve from 0.01315
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1171 - accuracy: 0.9537 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 82/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2305 - accuracy: 0.9062
# Epoch 82: val_loss did not improve from 0.01315
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1126 - accuracy: 0.9537 - val_loss: 0.1598 - val_accuracy: 0.9167
# Epoch 83/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1849 - accuracy: 0.9062
# Epoch 83: val_loss did not improve from 0.01315
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1130 - accuracy: 0.9352 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 84/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1418 - accuracy: 0.9062
# Epoch 84: val_loss improved from 0.01315 to 0.01313, saving model to model\iris-084-loss0.0131-acc1.0000.h5
# 4/4 [==============================] - 0s 24ms/step - loss: 0.1246 - accuracy: 0.9444 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 85/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2265 - accuracy: 0.9062
# Epoch 85: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1275 - accuracy: 0.9352 - val_loss: 0.1197 - val_accuracy: 0.9167
# Epoch 86/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0655 - accuracy: 0.9688
# Epoch 86: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0885 - accuracy: 0.9444 - val_loss: 0.0300 - val_accuracy: 1.0000
# Epoch 87/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2578 - accuracy: 0.9062
# Epoch 87: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1342 - accuracy: 0.9444 - val_loss: 0.0140 - val_accuracy: 1.0000
# Epoch 88/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0620 - accuracy: 0.9688
# Epoch 88: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1176 - accuracy: 0.9444 - val_loss: 0.0611 - val_accuracy: 0.9167
# Epoch 89/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0575 - accuracy: 0.9688
# Epoch 89: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0638 - accuracy: 0.9815 - val_loss: 0.0217 - val_accuracy: 1.0000
# Epoch 90/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0855 - accuracy: 0.9688
# Epoch 90: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1230 - accuracy: 0.9537 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 91/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0725 - accuracy: 0.9688
# Epoch 91: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0854 - accuracy: 0.9630 - val_loss: 0.0621 - val_accuracy: 0.9167
# Epoch 92/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1346 - accuracy: 0.9062
# Epoch 92: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0842 - accuracy: 0.9537 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 93/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1177 - accuracy: 0.9688
# Epoch 93: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0829 - accuracy: 0.9722 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 94/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1335 - accuracy: 0.9688
# Epoch 94: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0851 - accuracy: 0.9630 - val_loss: 0.0670 - val_accuracy: 0.9167
# Epoch 95/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0598 - accuracy: 0.9688
# Epoch 95: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0805 - accuracy: 0.9537 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 96/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1130 - accuracy: 0.9688
# Epoch 96: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0826 - accuracy: 0.9630 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 97/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0193 - accuracy: 1.0000
# Epoch 97: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0825 - accuracy: 0.9722 - val_loss: 0.0292 - val_accuracy: 1.0000
# Epoch 98/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0700 - accuracy: 1.0000
# Epoch 98: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1008 - accuracy: 0.9630 - val_loss: 0.0583 - val_accuracy: 1.0000
# Epoch 99/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0765 - accuracy: 0.9688
# Epoch 99: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0542 - accuracy: 0.9815 - val_loss: 0.0278 - val_accuracy: 1.0000
# Epoch 100/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0256 - accuracy: 1.0000
# Epoch 100: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1490 - accuracy: 0.9444 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 101/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0282 - accuracy: 1.0000
# Epoch 101: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0748 - accuracy: 0.9815 - val_loss: 0.0552 - val_accuracy: 1.0000
# Epoch 102/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1114 - accuracy: 0.9062
# Epoch 102: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0807 - accuracy: 0.9444 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 103/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1271 - accuracy: 0.9375
# Epoch 103: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0670 - accuracy: 0.9722 - val_loss: 0.0216 - val_accuracy: 1.0000
# Epoch 104/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2133 - accuracy: 0.9375
# Epoch 104: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1002 - accuracy: 0.9722 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 105/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0403 - accuracy: 1.0000
# Epoch 105: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0774 - accuracy: 0.9630 - val_loss: 0.0955 - val_accuracy: 0.9167
# Epoch 106/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0670 - accuracy: 0.9688
# Epoch 106: val_loss did not improve from 0.01313
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0894 - accuracy: 0.9630 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 107/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0146 - accuracy: 1.0000
# Epoch 107: val_loss improved from 0.01313 to 0.01256, saving model to model\iris-107-loss0.0126-acc1.0000.h5
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0901 - accuracy: 0.9722 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 108/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1985 - accuracy: 0.9375
# Epoch 108: val_loss did not improve from 0.01256
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0855 - accuracy: 0.9630 - val_loss: 0.0524 - val_accuracy: 1.0000
# Epoch 109/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1145 - accuracy: 0.9375
# Epoch 109: val_loss did not improve from 0.01256
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0837 - accuracy: 0.9444 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 110/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1229 - accuracy: 0.9688
# Epoch 110: val_loss improved from 0.01256 to 0.01246, saving model to model\iris-110-loss0.0125-acc1.0000.h5
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0717 - accuracy: 0.9722 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 111/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0581 - accuracy: 0.9688
# Epoch 111: val_loss did not improve from 0.01246
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0662 - accuracy: 0.9722 - val_loss: 0.0254 - val_accuracy: 1.0000
# Epoch 112/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0556 - accuracy: 1.0000
# Epoch 112: val_loss did not improve from 0.01246
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0679 - accuracy: 0.9815 - val_loss: 0.0250 - val_accuracy: 1.0000
# Epoch 113/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1677 - accuracy: 0.9375
# Epoch 113: val_loss improved from 0.01246 to 0.01153, saving model to model\iris-113-loss0.0115-acc1.0000.h5
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0671 - accuracy: 0.9722 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 114/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 114: val_loss did not improve from 0.01153
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0740 - accuracy: 0.9722 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 115/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0444 - accuracy: 1.0000
# Epoch 115: val_loss did not improve from 0.01153
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0688 - accuracy: 0.9722 - val_loss: 0.0360 - val_accuracy: 1.0000
# Epoch 116/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0291 - accuracy: 1.0000
# Epoch 116: val_loss improved from 0.01153 to 0.01098, saving model to model\iris-116-loss0.0110-acc1.0000.h5
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0670 - accuracy: 0.9815 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 117/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0207 - accuracy: 1.0000
# Epoch 117: val_loss did not improve from 0.01098
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0800 - accuracy: 0.9722 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 118/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0301 - accuracy: 1.0000
# Epoch 118: val_loss did not improve from 0.01098
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0708 - accuracy: 0.9722 - val_loss: 0.0305 - val_accuracy: 1.0000
# Epoch 119/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0596 - accuracy: 0.9688
# Epoch 119: val_loss did not improve from 0.01098
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0650 - accuracy: 0.9815 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 120/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0195 - accuracy: 1.0000
# Epoch 120: val_loss did not improve from 0.01098
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0805 - accuracy: 0.9722 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 121/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0433 - accuracy: 0.9688
# Epoch 121: val_loss did not improve from 0.01098
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0747 - accuracy: 0.9722 - val_loss: 0.0939 - val_accuracy: 0.9167
# Epoch 122/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0981 - accuracy: 0.9375
# Epoch 122: val_loss did not improve from 0.01098
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0952 - accuracy: 0.9537 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 123/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1283 - accuracy: 0.9688
# Epoch 123: val_loss did not improve from 0.01098
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0922 - accuracy: 0.9630 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 124/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0359 - accuracy: 0.9688
# Epoch 124: val_loss did not improve from 0.01098
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0880 - accuracy: 0.9537 - val_loss: 0.0202 - val_accuracy: 1.0000
# Epoch 125/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1163 - accuracy: 0.9688
# Epoch 125: val_loss did not improve from 0.01098
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1078 - accuracy: 0.9537 - val_loss: 0.0783 - val_accuracy: 0.9167
# Epoch 126/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1175 - accuracy: 0.9375
# Epoch 126: val_loss did not improve from 0.01098
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0980 - accuracy: 0.9537 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 127/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 127: val_loss did not improve from 0.01098
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0865 - accuracy: 0.9722 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 128/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0244 - accuracy: 1.0000
# Epoch 128: val_loss did not improve from 0.01098
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0650 - accuracy: 0.9815 - val_loss: 0.0490 - val_accuracy: 1.0000
# Epoch 129/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0238 - accuracy: 1.0000
# Epoch 129: val_loss did not improve from 0.01098
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0707 - accuracy: 0.9630 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 130/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0462 - accuracy: 0.9688
# Epoch 130: val_loss did not improve from 0.01098
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0686 - accuracy: 0.9722 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 131/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1991 - accuracy: 0.9062
# Epoch 131: val_loss did not improve from 0.01098
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0790 - accuracy: 0.9722 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 132/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0250 - accuracy: 1.0000
# Epoch 132: val_loss did not improve from 0.01098
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0626 - accuracy: 0.9815 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 133/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0207 - accuracy: 1.0000
# Epoch 133: val_loss did not improve from 0.01098
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0645 - accuracy: 0.9815 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 134/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0379 - accuracy: 1.0000
# Epoch 134: val_loss improved from 0.01098 to 0.01011, saving model to model\iris-134-loss0.0101-acc1.0000.h5
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0686 - accuracy: 0.9815 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 135/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0381 - accuracy: 0.9688
# Epoch 135: val_loss did not improve from 0.01011
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0668 - accuracy: 0.9815 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 136/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0417 - accuracy: 1.0000
# Epoch 136: val_loss did not improve from 0.01011
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0632 - accuracy: 0.9815 - val_loss: 0.0264 - val_accuracy: 1.0000
# Epoch 137/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1075 - accuracy: 0.9688
# Epoch 137: val_loss did not improve from 0.01011
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0607 - accuracy: 0.9815 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 138/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0427 - accuracy: 1.0000
# Epoch 138: val_loss improved from 0.01011 to 0.00974, saving model to model\iris-138-loss0.0097-acc1.0000.h5
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0810 - accuracy: 0.9722 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 139/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1255 - accuracy: 0.9688
# Epoch 139: val_loss did not improve from 0.00974
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0710 - accuracy: 0.9815 - val_loss: 0.0236 - val_accuracy: 1.0000
# Epoch 140/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1000 - accuracy: 0.9688
# Epoch 140: val_loss did not improve from 0.00974
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0596 - accuracy: 0.9815 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 141/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 141: val_loss did not improve from 0.00974
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0908 - accuracy: 0.9630 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 142/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1205 - accuracy: 0.9688
# Epoch 142: val_loss did not improve from 0.00974
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0597 - accuracy: 0.9907 - val_loss: 0.1152 - val_accuracy: 0.9167
# Epoch 143/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2397 - accuracy: 0.9062
# Epoch 143: val_loss did not improve from 0.00974
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1142 - accuracy: 0.9537 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 144/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1212 - accuracy: 0.9688
# Epoch 144: val_loss did not improve from 0.00974
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0826 - accuracy: 0.9630 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 145/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0389 - accuracy: 1.0000
# Epoch 145: val_loss did not improve from 0.00974
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0580 - accuracy: 0.9815 - val_loss: 0.0402 - val_accuracy: 1.0000
# Epoch 146/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1057 - accuracy: 0.9375
# Epoch 146: val_loss did not improve from 0.00974
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0838 - accuracy: 0.9444 - val_loss: 0.0282 - val_accuracy: 1.0000
# Epoch 147/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0421 - accuracy: 0.9688
# Epoch 147: val_loss did not improve from 0.00974
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0645 - accuracy: 0.9722 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 148/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1146 - accuracy: 0.9688
# Epoch 148: val_loss did not improve from 0.00974
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0621 - accuracy: 0.9722 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 149/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1186 - accuracy: 0.9688
# Epoch 149: val_loss did not improve from 0.00974
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0614 - accuracy: 0.9815 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 150/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0250 - accuracy: 1.0000
# Epoch 150: val_loss did not improve from 0.00974
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0603 - accuracy: 0.9815 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 151/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1041 - accuracy: 0.9375
# Epoch 151: val_loss did not improve from 0.00974
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0600 - accuracy: 0.9815 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 152/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1428 - accuracy: 0.9688
# Epoch 152: val_loss did not improve from 0.00974
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0659 - accuracy: 0.9815 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 153/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0602 - accuracy: 0.9688
# Epoch 153: val_loss did not improve from 0.00974
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0663 - accuracy: 0.9722 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 154/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1117 - accuracy: 0.9688
# Epoch 154: val_loss did not improve from 0.00974
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0697 - accuracy: 0.9815 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 155/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0316 - accuracy: 1.0000
# Epoch 155: val_loss improved from 0.00974 to 0.00826, saving model to model\iris-155-loss0.0083-acc1.0000.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0645 - accuracy: 0.9722 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 156/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0317 - accuracy: 1.0000
# Epoch 156: val_loss did not improve from 0.00826
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0656 - accuracy: 0.9815 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 157/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0367 - accuracy: 1.0000
# Epoch 157: val_loss did not improve from 0.00826
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0696 - accuracy: 0.9630 - val_loss: 0.0261 - val_accuracy: 1.0000
# Epoch 158/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0872 - accuracy: 0.9688
# Epoch 158: val_loss improved from 0.00826 to 0.00803, saving model to model\iris-158-loss0.0080-acc1.0000.h5
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0605 - accuracy: 0.9722 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 159/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0389 - accuracy: 0.9688
# Epoch 159: val_loss improved from 0.00803 to 0.00791, saving model to model\iris-159-loss0.0079-acc1.0000.h5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0671 - accuracy: 0.9722 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 160/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1182 - accuracy: 0.9688
# Epoch 160: val_loss did not improve from 0.00791
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0670 - accuracy: 0.9815 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 161/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0440 - accuracy: 1.0000
# Epoch 161: val_loss did not improve from 0.00791
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0637 - accuracy: 0.9815 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 162/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0330 - accuracy: 1.0000
# Epoch 162: val_loss did not improve from 0.00791
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0649 - accuracy: 0.9815 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 163/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 163: val_loss did not improve from 0.00791
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0660 - accuracy: 0.9815 - val_loss: 0.0238 - val_accuracy: 1.0000
# Epoch 164/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1123 - accuracy: 0.9375
# Epoch 164: val_loss did not improve from 0.00791
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0622 - accuracy: 0.9722 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 165/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0648 - accuracy: 0.9688
# Epoch 165: val_loss did not improve from 0.00791
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0610 - accuracy: 0.9722 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 166/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0311 - accuracy: 1.0000
# Epoch 166: val_loss did not improve from 0.00791
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0642 - accuracy: 0.9722 - val_loss: 0.0120 - val_accuracy: 1.0000
# Epoch 167/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0901 - accuracy: 0.9688
# Epoch 167: val_loss did not improve from 0.00791
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0673 - accuracy: 0.9722 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 168/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0975 - accuracy: 0.9688
# Epoch 168: val_loss did not improve from 0.00791
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0604 - accuracy: 0.9815 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 169/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1087 - accuracy: 0.9375
# Epoch 169: val_loss did not improve from 0.00791
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0738 - accuracy: 0.9722 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 170/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0848 - accuracy: 0.9688
# Epoch 170: val_loss did not improve from 0.00791
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0682 - accuracy: 0.9630 - val_loss: 0.0659 - val_accuracy: 0.9167
# Epoch 171/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0709 - accuracy: 0.9688
# Epoch 171: val_loss improved from 0.00791 to 0.00725, saving model to model\iris-171-loss0.0073-acc1.0000.h5
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0816 - accuracy: 0.9630 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 172/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0419 - accuracy: 1.0000
# Epoch 172: val_loss improved from 0.00725 to 0.00720, saving model to model\iris-172-loss0.0072-acc1.0000.h5
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0887 - accuracy: 0.9722 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 173/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0515 - accuracy: 0.9688
# Epoch 173: val_loss did not improve from 0.00720
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0771 - accuracy: 0.9630 - val_loss: 0.0606 - val_accuracy: 0.9167
# Epoch 174/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1152 - accuracy: 0.9062
# Epoch 174: val_loss did not improve from 0.00720
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0899 - accuracy: 0.9444 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 175/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0378 - accuracy: 1.0000
# Epoch 175: val_loss did not improve from 0.00720
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0678 - accuracy: 0.9815 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 176/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0789 - accuracy: 0.9375
# Epoch 176: val_loss did not improve from 0.00720
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0668 - accuracy: 0.9722 - val_loss: 0.0207 - val_accuracy: 1.0000
# Epoch 177/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1009 - accuracy: 0.9688
# Epoch 177: val_loss did not improve from 0.00720
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0655 - accuracy: 0.9815 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 178/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1027 - accuracy: 0.9688
# Epoch 178: val_loss did not improve from 0.00720
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0598 - accuracy: 0.9815 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 179/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0875 - accuracy: 0.9688
# Epoch 179: val_loss improved from 0.00720 to 0.00715, saving model to model\iris-179-loss0.0071-acc1.0000.h5
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0575 - accuracy: 0.9815 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 180/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0568 - accuracy: 0.9375
# Epoch 180: val_loss did not improve from 0.00715
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0621 - accuracy: 0.9722 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 181/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0272 - accuracy: 1.0000
# Epoch 181: val_loss did not improve from 0.00715
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0610 - accuracy: 0.9722 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 182/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0286 - accuracy: 1.0000
# Epoch 182: val_loss did not improve from 0.00715
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0552 - accuracy: 0.9815 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 183/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1079 - accuracy: 0.9688
# Epoch 183: val_loss did not improve from 0.00715
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0651 - accuracy: 0.9722 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 184/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0149 - accuracy: 1.0000
# Epoch 184: val_loss improved from 0.00715 to 0.00655, saving model to model\iris-184-loss0.0066-acc1.0000.h5
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0667 - accuracy: 0.9722 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 185/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0701 - accuracy: 0.9688
# Epoch 185: val_loss did not improve from 0.00655
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0558 - accuracy: 0.9815 - val_loss: 0.0368 - val_accuracy: 1.0000
# Epoch 186/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1244 - accuracy: 0.9062
# Epoch 186: val_loss did not improve from 0.00655
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0781 - accuracy: 0.9537 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 187/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1149 - accuracy: 0.9375
# Epoch 187: val_loss did not improve from 0.00655
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0572 - accuracy: 0.9722 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 188/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0258 - accuracy: 1.0000
# Epoch 188: val_loss did not improve from 0.00655
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0616 - accuracy: 0.9722 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 189/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0614 - accuracy: 0.9688
# Epoch 189: val_loss did not improve from 0.00655
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0650 - accuracy: 0.9630 - val_loss: 0.0329 - val_accuracy: 1.0000
# Epoch 190/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1516 - accuracy: 0.9062
# Epoch 190: val_loss did not improve from 0.00655
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0728 - accuracy: 0.9537 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 191/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0276 - accuracy: 1.0000
# Epoch 191: val_loss did not improve from 0.00655
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0837 - accuracy: 0.9722 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 192/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0145 - accuracy: 1.0000
# Epoch 192: val_loss did not improve from 0.00655
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0687 - accuracy: 0.9722 - val_loss: 0.0512 - val_accuracy: 1.0000
# Epoch 193/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0677 - accuracy: 0.9375
# Epoch 193: val_loss did not improve from 0.00655
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0793 - accuracy: 0.9444 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 194/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1847 - accuracy: 0.9375
# Epoch 194: val_loss did not improve from 0.00655
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0937 - accuracy: 0.9630 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 195/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 195: val_loss did not improve from 0.00655
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0578 - accuracy: 0.9722 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 196/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0869 - accuracy: 0.9375
# Epoch 196: val_loss did not improve from 0.00655
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0752 - accuracy: 0.9444 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 197/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0278 - accuracy: 1.0000
# Epoch 197: val_loss improved from 0.00655 to 0.00647, saving model to model\iris-197-loss0.0065-acc1.0000.h5
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0745 - accuracy: 0.9722 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 198/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0979 - accuracy: 0.9688
# Epoch 198: val_loss did not improve from 0.00647
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0904 - accuracy: 0.9537 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 199/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0793 - accuracy: 0.9688
# Epoch 199: val_loss did not improve from 0.00647
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0526 - accuracy: 0.9722 - val_loss: 0.0251 - val_accuracy: 1.0000
# Epoch 200/200
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3009 - accuracy: 0.8750
# Epoch 200: val_loss did not improve from 0.00647
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1030 - accuracy: 0.9630 - val_loss: 0.0086 - val_accuracy: 1.0000
# CPU times: total: 14.4 s
# Wall time: 11.6 s

# %% [markdown]
# ## 3. 모델 평가

# %%
# 학습과정 살펴보기(시각화)
fig, loss_ax = plt.subplots(figsize=(15,6))
loss_ax.plot(hist.history['loss'], 'y', label='train_loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val_loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train_accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val_accuracy')

acc_ax.set_ylabel('accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(bbox_to_anchor=(0.97,0.75))
acc_ax.legend(loc='center right')
plt.show()

# %%
# 모델 평가
loss, acc = model.evaluate(test_X, test_y)
print(loss, acc)
# Out:
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0285 - accuracy: 1.0000
# 0.028486477211117744 1.0

# %%
# 저장된 모델중 최선 모델
model1 = load_model('model/iris-110-loss0.0125-acc1.0000.h5')
loss1, acc1 = model1.evaluate(test_X, test_y)
print(loss1, acc1)
# Out:
# 1/1 [==============================] - 0s 189ms/step - loss: 0.0270 - accuracy: 1.0000
# 0.02702350541949272 1.0

# %% [markdown]
# # 2. sklearn이용
# - 4->64->128->50->30->3

# %%
from sklearn.neural_network import MLPClassifier  # multi-layer perceptron
# 1. 데이터
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((120, 4), (120,), (30, 4), (30,))

# %%
# 2. 모델 생성
model = MLPClassifier(hidden_layer_sizes=(64, 128, 50, 30),
                     activation='relu',
                     solver='adam', # 옵티마이저
                     batch_size=40, # 학습시 batch_size
                     early_stopping=True, # 조기 종료 활성화,
                     n_iter_no_change=50, # earlystopping의 patience역할
                     validation_fraction=0.1, # 검증셋 비율
                     max_iter=200, 
                     warm_start=False, # True일 경우 이전학습에 이어서 학습
                     )

# %%
# 3. 모델 학습
model.fit(train_X, train_y)
# Out:
# MLPClassifier(batch_size=40, early_stopping=True,
#               hidden_layer_sizes=(64, 128, 50, 30), n_iter_no_change=50)

# %%
# 4. 모델 평가
model.score(test_X, test_y)
# Out:
# 0.9333333333333333

# %%
# 5. 교차표(혼동행렬)
# 실제값 : test_y
y_hat = model.predict(test_X)
pd.crosstab(test_y, y_hat, rownames=['real'], colnames=['predict'])
# Out:
# predict   0  1   2
# real
# 0        10  0   0
# 1         0  8   2
# 2         0  0  10

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(test_y, y_hat)
# Out:
# array([[10,  0,  0],
#        [ 0,  8,  2],
#        [ 0,  0, 10]], dtype=int64)

# %% [markdown]
# # 3. 클래스를 생성하여 모델 생성함수 사용

# %%
class DNNClassifier:
    @staticmethod
    def build(input_dim=4, activation='relu', output_dim=3, optimizer='adam'):
        # 모델 구성
        model = Sequential(layers=[
            Input(input_dim),
            Dense(units=50, activation=activation),
            Dense(units=30, activation=activation),
            Dense(units=output_dim, activation='softmax')
        ], name='sequential')
        # 모델 학습 설정
        model.compile(loss='sparse_categorical_crossentropy',
                     optimizer=optimizer,
                     metrics=['accuracy'])
        # 모델 return
        return model

# %%
# %%time
# 1. 데이터
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# 2. 모델
model = DNNClassifier.build(input_dim=4, activation='relu', output_dim=3, optimizer='adam')
# 3. 모델 학습
hist = model.fit(train_X, train_y,
                epochs=50, 
                validation_split=0.1, 
                verbose=0)
# Out:
# (120, 4) (120,) (30, 4) (30,)
# CPU times: total: 3.3 s
# Wall time: 2.73 s

# %%
# 모델 평가
loss, accuracy = model.evaluate(test_X, test_y, verbose=0)
print(f'정확도 : {accuracy*100}%')
# Out:
# 정확도 : 96.66666388511658%

# %% [markdown]
# # 4. 함수형 API

# %%
# 기존 model 스타일 1
model = Sequential(layers=[
    Input(shape=(4,)),
    Dense(units=50, activation='relu'),
    Dense(units=30, activation='relu'),
    Dense(units=3, activation='softmax'),
])
# 기존 model 스타일 2
model = Sequential()
model.add(Input(shape=(4,)))
model.add(Dense(units=50, activation='relu'))
model.add(Dense(units=30, activation='relu'))
model.add(Dense(units=3, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_65 (Dense)            (None, 50)                250
#
#  dense_66 (Dense)            (None, 30)                1530
#
#  dense_67 (Dense)            (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 함수형 API 스타일
from tensorflow.keras import Model
input_ = Input(shape=(4,))
layer1 = Dense(units=50, activation='relu')(input_)
layer2 = Dense(units=30, activation='relu')(layer1)
output = Dense(units=3, activation='softmax')(layer2)
model = Model(inputs=input_, outputs=output)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 4)]               0
#
#  dense_53 (Dense)            (None, 50)                250
#
#  dense_54 (Dense)            (None, 30)                1530
#
#  dense_55 (Dense)            (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 4->160->3
# 기존의 model 방식
model = Sequential([
    Input(shape=(4,)),
    Dense(units=160, activation='relu'),
    Dense(units=3, activation='softmax')
])
# 함수형 API 방식
input_ = Input(shape=(4,))
layer  = Dense(units=160, activation='relu')(input_)
output = Dense(units=3,   activation='softmax')(layer)
model = Model(inputs=input_, outputs=output)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_23 (InputLayer)       [(None, 4)]               0
#
#  dense_74 (Dense)            (None, 160)               800
#
#  dense_75 (Dense)            (None, 3)                 483
#
# =================================================================
# Total params: 1,283
# Trainable params: 1,283
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 4->160->3를 병렬처리 방식
from tensorflow.keras.layers import concatenate
input_ = Input(shape=(4,))
dense1 = Dense(units=50, activation='relu')(input_)
dense2 = Dense(units=80, activation='relu')(input_)
dense3 = Dense(units=30, activation='relu')(input_)
x      = concatenate([dense1, dense2, dense3])
output = Dense(units=3, activation='softmax')(x)
model  = Model(inputs=input_, outputs=output)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_27 (InputLayer)          [(None, 4)]          0           []
#
#  dense_85 (Dense)               (None, 50)           250         ['input_27[0][0]']
#
#  dense_86 (Dense)               (None, 80)           400         ['input_27[0][0]']
#
#  dense_87 (Dense)               (None, 30)           150         ['input_27[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 160)          0           ['dense_85[0][0]',
#                                                                   'dense_86[0][0]',
#                                                                   'dense_87[0][0]']
#
#  dense_88 (Dense)               (None, 3)            483         ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 1,283
# Trainable params: 1,283
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 레지듀얼 블럭(Residual Block)
from tensorflow.keras.layers import add
input_ = Input(shape=(4,))
dense1 = Dense(units=50, activation='relu')(input_)
layer1 = Dense(units=64, activation='relu')(dense1)
layer2 = Dense(units=50, activation='relu')(layer1)
dense2 = add([dense1, layer2])
output = Dense(units=3, activation='softmax')(dense2)
model  = Model(inputs=input_, outputs=output)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_29 (InputLayer)          [(None, 4)]          0           []
#
#  dense_93 (Dense)               (None, 50)           250         ['input_29[0][0]']
#
#  dense_94 (Dense)               (None, 64)           3264        ['dense_93[0][0]']
#
#  dense_95 (Dense)               (None, 50)           3250        ['dense_94[0][0]']
#
#  add_1 (Add)                    (None, 50)           0           ['dense_93[0][0]',
#                                                                   'dense_95[0][0]']
#
#  dense_96 (Dense)               (None, 3)            153         ['add_1[0][0]']
#
# ==================================================================================================
# Total params: 6,917
# Trainable params: 6,917
# Non-trainable params: 0
# __________________________________________________________________________________________________
