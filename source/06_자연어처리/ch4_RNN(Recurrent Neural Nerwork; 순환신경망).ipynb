# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:95%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:22pt;}
.inner_cell{font-size:22pt;}
div.text_cell_render pre code {font-size:22pt; line-height:30px;}
div.output {font-size:20pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:22pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render li{font-size:20pt;padding:5px; line-height:30px;}
table.dataframe{font-size:22px;}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:95%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:22pt;}
# .inner_cell{font-size:22pt;}
# div.text_cell_render pre code {font-size:22pt; line-height:30px;}
# div.output {font-size:20pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:22pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render li{font-size:20pt;padding:5px; line-height:30px;}
# table.dataframe{font-size:22px;}
# </style>

# %% [markdown]
# **<font size="6" color="red">ch4. RNN(Recurrent Neural Network)</font>**
# - 순서나 시간 데이터가 중요할 때 ex. 번역, 음성인식, 주가예측
# # 1. 문맥을 이용하여 모델만들기

# %%
text = """경마장에 있는 말이 뛰고 있다
그의 말이 법이다
가는 말이 고와야 오는 말이 곱다"""
text1 = "겨울이 오는 날"

# %%
from keras_preprocessing.text import Tokenizer
t = Tokenizer()
t.fit_on_texts([text, text1])
encoded = t.texts_to_sequences([text, text1])
print(encoded)
print(t.word_index)
# Out:
# [[3, 4, 1, 5, 6, 7, 1, 8, 9, 1, 10, 2, 1, 11], [12, 2, 13]]
# {'말이': 1, '오는': 2, '경마장에': 3, '있는': 4, '뛰고': 5, '있다': 6, '그의': 7, '법이다': 8, '가는': 9, '고와야': 10, '곱다': 11, '겨울이': 12, '날': 13}

# %%
text = """경마장에 있는 말이 뛰고 있다
그의 말이 법이다
가는 말이 고와야 오는 말이 곱다"""

# %%
# 문자를 인덱스시퀀스로 변환하기 위한 과정
t = Tokenizer()
t.fit_on_texts([text])
print(t.word_index)
# Out:
# {'말이': 1, '경마장에': 2, '있는': 3, '뛰고': 4, '있다': 5, '그의': 6, '법이다': 7, '가는': 8, '고와야': 9, '오는': 10, '곱다': 11}

# %%
# 문자열 리스트를 인덱스 시퀀스로 변환
print(t.texts_to_sequences(['경마장에 말이 있다', '말이 뛴다']))
print(t.texts_to_sequences(['가는 말이 곱다'])[0])
# Out:
# [[2, 1, 5], [1]]
# [8, 1, 11]

# %%
for key, value in t.word_index.items():
    print(key, value)
# Out:
# 말이 1
# 경마장에 2
# 있는 3
# 뛰고 4
# 있다 5
# 그의 6
# 법이다 7
# 가는 8
# 고와야 9
# 오는 10
# 곱다 11

# %%
text = """경마장에 있는 말이 뛰고 있다
그의 말이 법이다
가는 말이 고와야 오는 말이 곱다"""

# %%
# text를 학습시키기 위한 ['경마장에 있는', '경마장에 있는 말이']
sequences = []
for line in text.split('\n'):
    print('원 문장 : ', line)
    encoded = t.texts_to_sequences([line])[0]
    print('encoded된 문장 :', encoded)
    for i in range(0, len(encoded)-1): # 시작 index
        for j in range(i+2, len(encoded)+1 ) : # 끝나는 index
            sequences.append(encoded[i:j])
# sequences
print('sequences와 해석 출력')
for sequence in sequences:
    # print(sequence)
    for word_seq in sequence:
        for key, value in t.word_index.items():
            if word_seq==value:
                print("{}:{}".format(word_seq, key), end=' ')
                break
    print()
# Out:
# 원 문장 :  경마장에 있는 말이 뛰고 있다
# encoded된 문장 : [2, 3, 1, 4, 5]
# 원 문장 :  그의 말이 법이다
# encoded된 문장 : [6, 1, 7]
# 원 문장 :  가는 말이 고와야 오는 말이 곱다
# encoded된 문장 : [8, 1, 9, 10, 1, 11]
# sequences와 해석 출력
# 2:경마장에 3:있는
# 2:경마장에 3:있는 1:말이
# 2:경마장에 3:있는 1:말이 4:뛰고
# 2:경마장에 3:있는 1:말이 4:뛰고 5:있다
# 3:있는 1:말이
# 3:있는 1:말이 4:뛰고
# 3:있는 1:말이 4:뛰고 5:있다
# 1:말이 4:뛰고
# 1:말이 4:뛰고 5:있다
# 4:뛰고 5:있다
# 6:그의 1:말이
# 6:그의 1:말이 7:법이다
# 1:말이 7:법이다
# 8:가는 1:말이
# 8:가는 1:말이 9:고와야
# 8:가는 1:말이 9:고와야 10:오는
# 8:가는 1:말이 9:고와야 10:오는 1:말이
# 8:가는 1:말이 9:고와야 10:오는 1:말이 11:곱다
# 1:말이 9:고와야
# 1:말이 9:고와야 10:오는
# 1:말이 9:고와야 10:오는 1:말이
# 1:말이 9:고와야 10:오는 1:말이 11:곱다
# 9:고와야 10:오는
# 9:고와야 10:오는 1:말이
# 9:고와야 10:오는 1:말이 11:곱다
# 10:오는 1:말이
# 10:오는 1:말이 11:곱다
# 1:말이 11:곱다

# %%
# sequences의 길이를 모두 같게(padding)
my_len = max([len(seq) for seq in sequences])
my_len
# Out:
# 6

# %%
# sequences를 훈련 가능하도록 6개(앞에 0, 뒤에 0)
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_sequences = pad_sequences(sequences=sequences,
                                 maxlen=my_len,
                                 padding='pre', # 앞에 0을 padding
                                 # truncating='post',
                                 )
padded_sequences[:3]
# Out:
# array([[0, 0, 0, 0, 2, 3],
#        [0, 0, 0, 2, 3, 1],
#        [0, 0, 2, 3, 1, 4]])

# %%
# 독립변수(X)와 타겟변수(y)를 분리
X = padded_sequences[:, :-1]
y = padded_sequences[:, -1]
# 단어 갯수
vocab_size = len(t.word_index)
vocab_size
# Out:
# 11

# %%
# 종속변수와 원핫인코딩
from tensorflow.keras.utils import to_categorical
Y = to_categorical(y, vocab_size+1)

# %%
X.shape, Y.shape, vocab_size

# %%
# 모델 생성 ( Embedding -> RNN -> Dense층 )
# Embedding층의 입력은 12(희소행렬) -> 출력은10. 이 단계에서 필요한 Embedding weight matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
# 교안 106p.
model = Sequential(name='sequential')
model.add(Embedding(input_dim=vocab_size+1, # 임베딩 입력
                    output_dim=10, # 임베딩 출력
                    input_length=X.shape[1])) # 입력(독립)변수
model.add(SimpleRNN(32, activation='tanh')) # 기본 activation='tanh'
model.add(Dense(12, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 5, 10)             120
#
#  simple_rnn (SimpleRNN)      (None, 32)                1376
#
#  dense (Dense)               (None, 12)                396
#
# =================================================================
# Total params: 1,892
# Trainable params: 1,892
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 학습과정 설정
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# 학습시키기
hist = model.fit(X, Y, epochs=300, verbose=2)
# Out:
# Epoch 1/300
# 1/1 - 1s - loss: 2.5171 - accuracy: 0.0357 - 980ms/epoch - 980ms/step
# Epoch 2/300
# 1/1 - 0s - loss: 2.5044 - accuracy: 0.0357 - 3ms/epoch - 3ms/step
# Epoch 3/300
# 1/1 - 0s - loss: 2.4924 - accuracy: 0.0357 - 5ms/epoch - 5ms/step
# Epoch 4/300
# 1/1 - 0s - loss: 2.4811 - accuracy: 0.0357 - 4ms/epoch - 4ms/step
# Epoch 5/300
# 1/1 - 0s - loss: 2.4701 - accuracy: 0.0714 - 3ms/epoch - 3ms/step
# Epoch 6/300
# 1/1 - 0s - loss: 2.4595 - accuracy: 0.1071 - 3ms/epoch - 3ms/step
# Epoch 7/300
# 1/1 - 0s - loss: 2.4490 - accuracy: 0.1786 - 4ms/epoch - 4ms/step
# Epoch 8/300
# 1/1 - 0s - loss: 2.4385 - accuracy: 0.2143 - 2ms/epoch - 2ms/step
# Epoch 9/300
# 1/1 - 0s - loss: 2.4280 - accuracy: 0.2143 - 3ms/epoch - 3ms/step
# Epoch 10/300
# 1/1 - 0s - loss: 2.4174 - accuracy: 0.2857 - 4ms/epoch - 4ms/step
# Epoch 11/300
# 1/1 - 0s - loss: 2.4065 - accuracy: 0.2857 - 4ms/epoch - 4ms/step
# Epoch 12/300
# 1/1 - 0s - loss: 2.3952 - accuracy: 0.3929 - 3ms/epoch - 3ms/step
# Epoch 13/300
# 1/1 - 0s - loss: 2.3836 - accuracy: 0.4286 - 2ms/epoch - 2ms/step
# Epoch 14/300
# 1/1 - 0s - loss: 2.3714 - accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 15/300
# 1/1 - 0s - loss: 2.3587 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 16/300
# 1/1 - 0s - loss: 2.3454 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 17/300
# 1/1 - 0s - loss: 2.3314 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 18/300
# 1/1 - 0s - loss: 2.3167 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 19/300
# 1/1 - 0s - loss: 2.3013 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 20/300
# 1/1 - 0s - loss: 2.2850 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 21/300
# 1/1 - 0s - loss: 2.2679 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 22/300
# 1/1 - 0s - loss: 2.2500 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 23/300
# 1/1 - 0s - loss: 2.2313 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 24/300
# 1/1 - 0s - loss: 2.2119 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 25/300
# 1/1 - 0s - loss: 2.1918 - accuracy: 0.5357 - 2ms/epoch - 2ms/step
# Epoch 26/300
# 1/1 - 0s - loss: 2.1711 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 27/300
# 1/1 - 0s - loss: 2.1499 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 28/300
# 1/1 - 0s - loss: 2.1284 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 29/300
# 1/1 - 0s - loss: 2.1067 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 30/300
# 1/1 - 0s - loss: 2.0852 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 31/300
# 1/1 - 0s - loss: 2.0639 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 32/300
# 1/1 - 0s - loss: 2.0432 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 33/300
# 1/1 - 0s - loss: 2.0233 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 34/300
# 1/1 - 0s - loss: 2.0042 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 35/300
# 1/1 - 0s - loss: 1.9861 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 36/300
# 1/1 - 0s - loss: 1.9692 - accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 37/300
# 1/1 - 0s - loss: 1.9534 - accuracy: 0.4643 - 3ms/epoch - 3ms/step
# Epoch 38/300
# 1/1 - 0s - loss: 1.9386 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 39/300
# 1/1 - 0s - loss: 1.9248 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 40/300
# 1/1 - 0s - loss: 1.9119 - accuracy: 0.4286 - 3ms/epoch - 3ms/step
# Epoch 41/300
# 1/1 - 0s - loss: 1.8999 - accuracy: 0.4286 - 4ms/epoch - 4ms/step
# Epoch 42/300
# 1/1 - 0s - loss: 1.8886 - accuracy: 0.3929 - 4ms/epoch - 4ms/step
# Epoch 43/300
# 1/1 - 0s - loss: 1.8779 - accuracy: 0.3929 - 3ms/epoch - 3ms/step
# Epoch 44/300
# 1/1 - 0s - loss: 1.8679 - accuracy: 0.3571 - 4ms/epoch - 4ms/step
# Epoch 45/300
# 1/1 - 0s - loss: 1.8583 - accuracy: 0.3571 - 3ms/epoch - 3ms/step
# Epoch 46/300
# 1/1 - 0s - loss: 1.8491 - accuracy: 0.3571 - 3ms/epoch - 3ms/step
# Epoch 47/300
# 1/1 - 0s - loss: 1.8401 - accuracy: 0.3571 - 4ms/epoch - 4ms/step
# Epoch 48/300
# 1/1 - 0s - loss: 1.8314 - accuracy: 0.3571 - 4ms/epoch - 4ms/step
# Epoch 49/300
# 1/1 - 0s - loss: 1.8226 - accuracy: 0.3571 - 3ms/epoch - 3ms/step
# Epoch 50/300
# 1/1 - 0s - loss: 1.8138 - accuracy: 0.3571 - 3ms/epoch - 3ms/step
# Epoch 51/300
# 1/1 - 0s - loss: 1.8048 - accuracy: 0.3571 - 4ms/epoch - 4ms/step
# Epoch 52/300
# 1/1 - 0s - loss: 1.7956 - accuracy: 0.3571 - 3ms/epoch - 3ms/step
# Epoch 53/300
# 1/1 - 0s - loss: 1.7863 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 54/300
# 1/1 - 0s - loss: 1.7767 - accuracy: 0.3571 - 3ms/epoch - 3ms/step
# Epoch 55/300
# 1/1 - 0s - loss: 1.7669 - accuracy: 0.3929 - 4ms/epoch - 4ms/step
# Epoch 56/300
# 1/1 - 0s - loss: 1.7568 - accuracy: 0.3929 - 4ms/epoch - 4ms/step
# Epoch 57/300
# 1/1 - 0s - loss: 1.7466 - accuracy: 0.3929 - 3ms/epoch - 3ms/step
# Epoch 58/300
# 1/1 - 0s - loss: 1.7362 - accuracy: 0.4286 - 4ms/epoch - 4ms/step
# Epoch 59/300
# 1/1 - 0s - loss: 1.7255 - accuracy: 0.4286 - 4ms/epoch - 4ms/step
# Epoch 60/300
# 1/1 - 0s - loss: 1.7145 - accuracy: 0.4286 - 3ms/epoch - 3ms/step
# Epoch 61/300
# 1/1 - 0s - loss: 1.7033 - accuracy: 0.4286 - 5ms/epoch - 5ms/step
# Epoch 62/300
# 1/1 - 0s - loss: 1.6918 - accuracy: 0.4643 - 2ms/epoch - 2ms/step
# Epoch 63/300
# 1/1 - 0s - loss: 1.6801 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 64/300
# 1/1 - 0s - loss: 1.6680 - accuracy: 0.4643 - 3ms/epoch - 3ms/step
# Epoch 65/300
# 1/1 - 0s - loss: 1.6556 - accuracy: 0.4643 - 6ms/epoch - 6ms/step
# Epoch 66/300
# 1/1 - 0s - loss: 1.6430 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 67/300
# 1/1 - 0s - loss: 1.6301 - accuracy: 0.4643 - 3ms/epoch - 3ms/step
# Epoch 68/300
# 1/1 - 0s - loss: 1.6169 - accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 69/300
# 1/1 - 0s - loss: 1.6035 - accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 70/300
# 1/1 - 0s - loss: 1.5898 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 71/300
# 1/1 - 0s - loss: 1.5759 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 72/300
# 1/1 - 0s - loss: 1.5618 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 73/300
# 1/1 - 0s - loss: 1.5475 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 74/300
# 1/1 - 0s - loss: 1.5330 - accuracy: 0.5714 - 5ms/epoch - 5ms/step
# Epoch 75/300
# 1/1 - 0s - loss: 1.5184 - accuracy: 0.5714 - 12ms/epoch - 12ms/step
# Epoch 76/300
# 1/1 - 0s - loss: 1.5037 - accuracy: 0.5714 - 6ms/epoch - 6ms/step
# Epoch 77/300
# 1/1 - 0s - loss: 1.4889 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 78/300
# 1/1 - 0s - loss: 1.4740 - accuracy: 0.5714 - 2ms/epoch - 2ms/step
# Epoch 79/300
# 1/1 - 0s - loss: 1.4591 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 80/300
# 1/1 - 0s - loss: 1.4441 - accuracy: 0.6071 - 4ms/epoch - 4ms/step
# Epoch 81/300
# 1/1 - 0s - loss: 1.4291 - accuracy: 0.6071 - 3ms/epoch - 3ms/step
# Epoch 82/300
# 1/1 - 0s - loss: 1.4142 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 83/300
# 1/1 - 0s - loss: 1.3993 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 84/300
# 1/1 - 0s - loss: 1.3844 - accuracy: 0.6429 - 2ms/epoch - 2ms/step
# Epoch 85/300
# 1/1 - 0s - loss: 1.3696 - accuracy: 0.6429 - 3ms/epoch - 3ms/step
# Epoch 86/300
# 1/1 - 0s - loss: 1.3549 - accuracy: 0.6429 - 3ms/epoch - 3ms/step
# Epoch 87/300
# 1/1 - 0s - loss: 1.3403 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 88/300
# 1/1 - 0s - loss: 1.3257 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 89/300
# 1/1 - 0s - loss: 1.3113 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 90/300
# 1/1 - 0s - loss: 1.2970 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 91/300
# 1/1 - 0s - loss: 1.2829 - accuracy: 0.6429 - 3ms/epoch - 3ms/step
# Epoch 92/300
# 1/1 - 0s - loss: 1.2689 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 93/300
# 1/1 - 0s - loss: 1.2550 - accuracy: 0.6429 - 7ms/epoch - 7ms/step
# Epoch 94/300
# 1/1 - 0s - loss: 1.2413 - accuracy: 0.6429 - 3ms/epoch - 3ms/step
# Epoch 95/300
# 1/1 - 0s - loss: 1.2278 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 96/300
# 1/1 - 0s - loss: 1.2144 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 97/300
# 1/1 - 0s - loss: 1.2013 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 98/300
# 1/1 - 0s - loss: 1.1883 - accuracy: 0.6429 - 3ms/epoch - 3ms/step
# Epoch 99/300
# 1/1 - 0s - loss: 1.1755 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 100/300
# 1/1 - 0s - loss: 1.1629 - accuracy: 0.6429 - 6ms/epoch - 6ms/step
# Epoch 101/300
# 1/1 - 0s - loss: 1.1505 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 102/300
# 1/1 - 0s - loss: 1.1383 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 103/300
# 1/1 - 0s - loss: 1.1263 - accuracy: 0.6429 - 6ms/epoch - 6ms/step
# Epoch 104/300
# 1/1 - 0s - loss: 1.1145 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 105/300
# 1/1 - 0s - loss: 1.1029 - accuracy: 0.6786 - 6ms/epoch - 6ms/step
# Epoch 106/300
# 1/1 - 0s - loss: 1.0915 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 107/300
# 1/1 - 0s - loss: 1.0803 - accuracy: 0.6786 - 7ms/epoch - 7ms/step
# Epoch 108/300
# 1/1 - 0s - loss: 1.0692 - accuracy: 0.6786 - 3ms/epoch - 3ms/step
# Epoch 109/300
# 1/1 - 0s - loss: 1.0584 - accuracy: 0.6786 - 3ms/epoch - 3ms/step
# Epoch 110/300
# 1/1 - 0s - loss: 1.0478 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 111/300
# 1/1 - 0s - loss: 1.0373 - accuracy: 0.6786 - 3ms/epoch - 3ms/step
# Epoch 112/300
# 1/1 - 0s - loss: 1.0270 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 113/300
# 1/1 - 0s - loss: 1.0169 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 114/300
# 1/1 - 0s - loss: 1.0070 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 115/300
# 1/1 - 0s - loss: 0.9973 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 116/300
# 1/1 - 0s - loss: 0.9877 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 117/300
# 1/1 - 0s - loss: 0.9783 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 118/300
# 1/1 - 0s - loss: 0.9690 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 119/300
# 1/1 - 0s - loss: 0.9599 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 120/300
# 1/1 - 0s - loss: 0.9510 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 121/300
# 1/1 - 0s - loss: 0.9422 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 122/300
# 1/1 - 0s - loss: 0.9335 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 123/300
# 1/1 - 0s - loss: 0.9250 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 124/300
# 1/1 - 0s - loss: 0.9166 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 125/300
# 1/1 - 0s - loss: 0.9084 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 126/300
# 1/1 - 0s - loss: 0.9003 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 127/300
# 1/1 - 0s - loss: 0.8923 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 128/300
# 1/1 - 0s - loss: 0.8844 - accuracy: 0.7143 - 2ms/epoch - 2ms/step
# Epoch 129/300
# 1/1 - 0s - loss: 0.8767 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 130/300
# 1/1 - 0s - loss: 0.8690 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 131/300
# 1/1 - 0s - loss: 0.8615 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 132/300
# 1/1 - 0s - loss: 0.8541 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 133/300
# 1/1 - 0s - loss: 0.8468 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 134/300
# 1/1 - 0s - loss: 0.8396 - accuracy: 0.7143 - 2ms/epoch - 2ms/step
# Epoch 135/300
# 1/1 - 0s - loss: 0.8325 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 136/300
# 1/1 - 0s - loss: 0.8255 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 137/300
# 1/1 - 0s - loss: 0.8186 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 138/300
# 1/1 - 0s - loss: 0.8118 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 139/300
# 1/1 - 0s - loss: 0.8051 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 140/300
# 1/1 - 0s - loss: 0.7984 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 141/300
# 1/1 - 0s - loss: 0.7919 - accuracy: 0.7143 - 2ms/epoch - 2ms/step
# Epoch 142/300
# 1/1 - 0s - loss: 0.7854 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 143/300
# 1/1 - 0s - loss: 0.7790 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 144/300
# 1/1 - 0s - loss: 0.7727 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 145/300
# 1/1 - 0s - loss: 0.7665 - accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 146/300
# 1/1 - 0s - loss: 0.7603 - accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 147/300
# 1/1 - 0s - loss: 0.7543 - accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 148/300
# 1/1 - 0s - loss: 0.7482 - accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 149/300
# 1/1 - 0s - loss: 0.7423 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 150/300
# 1/1 - 0s - loss: 0.7364 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 151/300
# 1/1 - 0s - loss: 0.7306 - accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 152/300
# 1/1 - 0s - loss: 0.7249 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 153/300
# 1/1 - 0s - loss: 0.7192 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 154/300
# 1/1 - 0s - loss: 0.7136 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 155/300
# 1/1 - 0s - loss: 0.7080 - accuracy: 0.7857 - 6ms/epoch - 6ms/step
# Epoch 156/300
# 1/1 - 0s - loss: 0.7025 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 157/300
# 1/1 - 0s - loss: 0.6970 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 158/300
# 1/1 - 0s - loss: 0.6917 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 159/300
# 1/1 - 0s - loss: 0.6863 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 160/300
# 1/1 - 0s - loss: 0.6810 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 161/300
# 1/1 - 0s - loss: 0.6758 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 162/300
# 1/1 - 0s - loss: 0.6706 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 163/300
# 1/1 - 0s - loss: 0.6655 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 164/300
# 1/1 - 0s - loss: 0.6604 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 165/300
# 1/1 - 0s - loss: 0.6554 - accuracy: 0.8214 - 2ms/epoch - 2ms/step
# Epoch 166/300
# 1/1 - 0s - loss: 0.6504 - accuracy: 0.8214 - 3ms/epoch - 3ms/step
# Epoch 167/300
# 1/1 - 0s - loss: 0.6455 - accuracy: 0.8214 - 6ms/epoch - 6ms/step
# Epoch 168/300
# 1/1 - 0s - loss: 0.6406 - accuracy: 0.8214 - 3ms/epoch - 3ms/step
# Epoch 169/300
# 1/1 - 0s - loss: 0.6358 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 170/300
# 1/1 - 0s - loss: 0.6310 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 171/300
# 1/1 - 0s - loss: 0.6262 - accuracy: 0.8214 - 3ms/epoch - 3ms/step
# Epoch 172/300
# 1/1 - 0s - loss: 0.6215 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 173/300
# 1/1 - 0s - loss: 0.6168 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 174/300
# 1/1 - 0s - loss: 0.6122 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 175/300
# 1/1 - 0s - loss: 0.6076 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 176/300
# 1/1 - 0s - loss: 0.6031 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 177/300
# 1/1 - 0s - loss: 0.5986 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 178/300
# 1/1 - 0s - loss: 0.5941 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 179/300
# 1/1 - 0s - loss: 0.5897 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 180/300
# 1/1 - 0s - loss: 0.5853 - accuracy: 0.8571 - 2ms/epoch - 2ms/step
# Epoch 181/300
# 1/1 - 0s - loss: 0.5810 - accuracy: 0.8571 - 6ms/epoch - 6ms/step
# Epoch 182/300
# 1/1 - 0s - loss: 0.5766 - accuracy: 0.8571 - 7ms/epoch - 7ms/step
# Epoch 183/300
# 1/1 - 0s - loss: 0.5724 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 184/300
# 1/1 - 0s - loss: 0.5681 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 185/300
# 1/1 - 0s - loss: 0.5640 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 186/300
# 1/1 - 0s - loss: 0.5598 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 187/300
# 1/1 - 0s - loss: 0.5557 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 188/300
# 1/1 - 0s - loss: 0.5516 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 189/300
# 1/1 - 0s - loss: 0.5476 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 190/300
# 1/1 - 0s - loss: 0.5435 - accuracy: 0.8571 - 2ms/epoch - 2ms/step
# Epoch 191/300
# 1/1 - 0s - loss: 0.5396 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 192/300
# 1/1 - 0s - loss: 0.5356 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 193/300
# 1/1 - 0s - loss: 0.5317 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 194/300
# 1/1 - 0s - loss: 0.5279 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 195/300
# 1/1 - 0s - loss: 0.5240 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 196/300
# 1/1 - 0s - loss: 0.5203 - accuracy: 0.8571 - 2ms/epoch - 2ms/step
# Epoch 197/300
# 1/1 - 0s - loss: 0.5165 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 198/300
# 1/1 - 0s - loss: 0.5128 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 199/300
# 1/1 - 0s - loss: 0.5091 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 200/300
# 1/1 - 0s - loss: 0.5054 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 201/300
# 1/1 - 0s - loss: 0.5018 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 202/300
# 1/1 - 0s - loss: 0.4982 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 203/300
# 1/1 - 0s - loss: 0.4947 - accuracy: 0.8571 - 2ms/epoch - 2ms/step
# Epoch 204/300
# 1/1 - 0s - loss: 0.4912 - accuracy: 0.8571 - 8ms/epoch - 8ms/step
# Epoch 205/300
# 1/1 - 0s - loss: 0.4877 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 206/300
# 1/1 - 0s - loss: 0.4842 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 207/300
# 1/1 - 0s - loss: 0.4808 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 208/300
# 1/1 - 0s - loss: 0.4774 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 209/300
# 1/1 - 0s - loss: 0.4741 - accuracy: 0.8571 - 2ms/epoch - 2ms/step
# Epoch 210/300
# 1/1 - 0s - loss: 0.4708 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 211/300
# 1/1 - 0s - loss: 0.4675 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 212/300
# 1/1 - 0s - loss: 0.4643 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 213/300
# 1/1 - 0s - loss: 0.4610 - accuracy: 0.8571 - 6ms/epoch - 6ms/step
# Epoch 214/300
# 1/1 - 0s - loss: 0.4579 - accuracy: 0.8571 - 2ms/epoch - 2ms/step
# Epoch 215/300
# 1/1 - 0s - loss: 0.4547 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 216/300
# 1/1 - 0s - loss: 0.4516 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 217/300
# 1/1 - 0s - loss: 0.4485 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 218/300
# 1/1 - 0s - loss: 0.4455 - accuracy: 0.8571 - 7ms/epoch - 7ms/step
# Epoch 219/300
# 1/1 - 0s - loss: 0.4425 - accuracy: 0.8571 - 7ms/epoch - 7ms/step
# Epoch 220/300
# 1/1 - 0s - loss: 0.4395 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 221/300
# 1/1 - 0s - loss: 0.4365 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 222/300
# 1/1 - 0s - loss: 0.4336 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 223/300
# 1/1 - 0s - loss: 0.4307 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 224/300
# 1/1 - 0s - loss: 0.4279 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 225/300
# 1/1 - 0s - loss: 0.4251 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 226/300
# 1/1 - 0s - loss: 0.4223 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 227/300
# 1/1 - 0s - loss: 0.4195 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 228/300
# 1/1 - 0s - loss: 0.4168 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 229/300
# 1/1 - 0s - loss: 0.4141 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 230/300
# 1/1 - 0s - loss: 0.4114 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 231/300
# 1/1 - 0s - loss: 0.4088 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 232/300
# 1/1 - 0s - loss: 0.4062 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 233/300
# 1/1 - 0s - loss: 0.4036 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 234/300
# 1/1 - 0s - loss: 0.4011 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 235/300
# 1/1 - 0s - loss: 0.3986 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 236/300
# 1/1 - 0s - loss: 0.3961 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 237/300
# 1/1 - 0s - loss: 0.3936 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 238/300
# 1/1 - 0s - loss: 0.3912 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 239/300
# 1/1 - 0s - loss: 0.3888 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 240/300
# 1/1 - 0s - loss: 0.3865 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 241/300
# 1/1 - 0s - loss: 0.3841 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 242/300
# 1/1 - 0s - loss: 0.3818 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 243/300
# 1/1 - 0s - loss: 0.3795 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 244/300
# 1/1 - 0s - loss: 0.3773 - accuracy: 0.8929 - 7ms/epoch - 7ms/step
# Epoch 245/300
# 1/1 - 0s - loss: 0.3751 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 246/300
# 1/1 - 0s - loss: 0.3729 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 247/300
# 1/1 - 0s - loss: 0.3707 - accuracy: 0.8929 - 2ms/epoch - 2ms/step
# Epoch 248/300
# 1/1 - 0s - loss: 0.3686 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 249/300
# 1/1 - 0s - loss: 0.3665 - accuracy: 0.8929 - 2ms/epoch - 2ms/step
# Epoch 250/300
# 1/1 - 0s - loss: 0.3644 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 251/300
# 1/1 - 0s - loss: 0.3623 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 252/300
# 1/1 - 0s - loss: 0.3603 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 253/300
# 1/1 - 0s - loss: 0.3583 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 254/300
# 1/1 - 0s - loss: 0.3563 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 255/300
# 1/1 - 0s - loss: 0.3544 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 256/300
# 1/1 - 0s - loss: 0.3524 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 257/300
# 1/1 - 0s - loss: 0.3505 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 258/300
# 1/1 - 0s - loss: 0.3487 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 259/300
# 1/1 - 0s - loss: 0.3468 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 260/300
# 1/1 - 0s - loss: 0.3450 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 261/300
# 1/1 - 0s - loss: 0.3432 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 262/300
# 1/1 - 0s - loss: 0.3414 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 263/300
# 1/1 - 0s - loss: 0.3396 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 264/300
# 1/1 - 0s - loss: 0.3379 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 265/300
# 1/1 - 0s - loss: 0.3362 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 266/300
# 1/1 - 0s - loss: 0.3345 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 267/300
# 1/1 - 0s - loss: 0.3329 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 268/300
# 1/1 - 0s - loss: 0.3312 - accuracy: 0.8929 - 8ms/epoch - 8ms/step
# Epoch 269/300
# 1/1 - 0s - loss: 0.3296 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 270/300
# 1/1 - 0s - loss: 0.3280 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 271/300
# 1/1 - 0s - loss: 0.3264 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 272/300
# 1/1 - 0s - loss: 0.3249 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 273/300
# 1/1 - 0s - loss: 0.3234 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 274/300
# 1/1 - 0s - loss: 0.3219 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 275/300
# 1/1 - 0s - loss: 0.3204 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 276/300
# 1/1 - 0s - loss: 0.3189 - accuracy: 0.8929 - 2ms/epoch - 2ms/step
# Epoch 277/300
# 1/1 - 0s - loss: 0.3175 - accuracy: 0.8929 - 2ms/epoch - 2ms/step
# Epoch 278/300
# 1/1 - 0s - loss: 0.3160 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 279/300
# 1/1 - 0s - loss: 0.3146 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 280/300
# 1/1 - 0s - loss: 0.3132 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 281/300
# 1/1 - 0s - loss: 0.3119 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 282/300
# 1/1 - 0s - loss: 0.3105 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 283/300
# 1/1 - 0s - loss: 0.3092 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 284/300
# 1/1 - 0s - loss: 0.3079 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 285/300
# 1/1 - 0s - loss: 0.3066 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 286/300
# 1/1 - 0s - loss: 0.3053 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 287/300
# 1/1 - 0s - loss: 0.3041 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 288/300
# 1/1 - 0s - loss: 0.3028 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 289/300
# 1/1 - 0s - loss: 0.3016 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 290/300
# 1/1 - 0s - loss: 0.3004 - accuracy: 0.8929 - 7ms/epoch - 7ms/step
# Epoch 291/300
# 1/1 - 0s - loss: 0.2992 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.2981 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.2969 - accuracy: 0.8929 - 2ms/epoch - 2ms/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.2958 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.2947 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.2936 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.2925 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.2914 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.2904 - accuracy: 0.8929 - 7ms/epoch - 7ms/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.2893 - accuracy: 0.8929 - 3ms/epoch - 3ms/step

# %%
# 학습과정 살펴보기(시각화)
import matplotlib.pyplot as plt
fig, loss_ax = plt.subplots(figsize=(15,6))
loss_ax.plot(hist.history['loss'], 'y', label='train_loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train_accuracy')

acc_ax.set_ylabel('accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(bbox_to_anchor=(0.97,0.75))
acc_ax.legend(loc='center right')
plt.show()

# %%
# 모델 사용하기(경마장에 있는 -> 말이)
from tensorflow.keras.preprocessing.sequence import pad_sequences
encoded = t.texts_to_sequences(['6시가 되면'])[0]
input_data = pad_sequences([encoded], maxlen=5, padding='pre')
print('모델에 들어갈 입력 데이터 :', input_data)
result = model.predict(input_data).argmax(axis=1)
print('모델 예측 결과 :', result)
for key, value in t.word_index.items():
    if value==result:
        print('가장 확률이 높은 단어(예측된 단어) :', key)
        break
# Out:
# 모델에 들어갈 입력 데이터 : [[0 0 0 0 0]]
# 1/1 [==============================] - 0s 17ms/step
# 모델 예측 결과 : [1]
# 가장 확률이 높은 단어(예측된 단어) : 말이

# %% [markdown]
# # 2. 다음 문맥 예측해 보기

# %%
# '경마장에 있는' 이후에 올 단어 4개 예측
def sentence_generation(model, t, current_word, n):
    print('입력된 단어 :', current_word)
    for i in range(1, n+1):
        encoded = t.texts_to_sequences(['6시가 되면'])[0]
        input_data = pad_sequences([encoded], maxlen=5, padding='pre')
        result = model.predict(input_data).argmax(axis=1)[0]
        for key, value in t.word_index.items():
            if value==result:
                print(f'{i}번째 {key}:{result}')
                current_word = current_word + ' ' + key
                break
    return current_word

# %%
sentence_generation(model, t, '경마장에', 4)
# Out:
# 입력된 단어 : 경마장에
# 1/1 [==============================] - 0s 20ms/step
# 1번째 말이:1
# 1/1 [==============================] - 0s 27ms/step
# 2번째 말이:1
# 1/1 [==============================] - 0s 25ms/step
# 3번째 말이:1
# 1/1 [==============================] - 0s 18ms/step
# 4번째 말이:1
# '경마장에 말이 말이 말이 말이'
