# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:10pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:10pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %% [markdown]
# <font size='6' color="red">ch07. 객체지향 프로그래밍</font>

# %%
person1 = {'name':'홍길동', 'gender':'남자', 'academy':'MBC'}
person2 = {'name':'홍길숙', 'gender':'여자', 'academy':'MBC'}
print(person1.get('name'), person1['gender'], person1.get('academy','-'))
print(person1)
print(person2)
# Out:
# 홍길동 남자 MBC
# {'name': '홍길동', 'gender': '남자', 'academy': 'MBC'}
# {'name': '홍길숙', 'gender': '여자', 'academy': 'MBC'}

# %%
class Person:  # 클래스 이름은 항상 대문자
    academy = 'MBC' # 클래스 변수
    def __init__(self, name, gender): # self : 내 객체 자신
        self.name = name # 인스턴스 변수
        self.gender = gender
        print('Person 객체 생성합니다')
    def print_info(self): 
        print("{}의 {}은/는 {}입니다".format(self.academy,
                                      self.name,
                                      self.gender))
p1 = Person('홍길동', '남자')
print(p1)
p1.print_info()
p1.name = '김길동'
p1.academy = '딴 곳'
p1.print_info()
# Out:
# Person 객체 생성합니다
# ...
# MBC의 홍길동은/는 남자입니다
# 딴 곳의 김길동은/는 남자입니다

# %%
p2 = Person('김길순', '여자')
p2.print_info()
p2.name = "김길숙"
p2.print_info()
# Out:
# Person 객체 생성합니다
# MBC의 김길순은/는 여자입니다
# MBC의 김길숙은/는 여자입니다

# %%
p1.academy, p2.academy, Person.academy
# Out:
# ('딴 곳', 'MBC', 'MBC')

# %% [markdown]
# # 1절. 객체와 클래스
#
# ```
# class 클래스명(상속받을 클래스명):
#     변수나 함수들을 선언
# ```

# %%
class Person:
    'Person 클래스는 어쩌구 저쩌구 여러줄 설명하는 독스트링'
#     def __innit__(self): # init 없으면 자동 생성
#         pass
    pass
p1 = Person()
# Out:
# Person 객체 소멸

# %%
print(p1.__str__())
print(p1)

# %%
isinstance(p1, Person) # p1 객체는 Person클래스 타입이다
# Out:
# True

# %%
p1.__doc__
# Out:
# 'Person 클래스는 어쩌구 저쩌구 여러줄 설명하는 독스트링'

# %% [markdown]
# # 2절. 생성자(`__init__(self, ...)`)와 소멸자(`__del__()`)
# ```
# 생성자 : __innit__(self, 매개변수, ..) 객체가 생성될 때 자동 실행
#         생성시 필요한 코드(인스턴스 변수 초기화)를 포함
#         없으면 default 생성자가 자동 생성
# 소멸자 : __del__(self) 객체가 소멸될 (참조한 변수가 없어질 때) 때 자동 실행
#         인스턴스 객체의 레퍼런스 카운트가 0이 될 때 실행
#         소멸시 필요한 코드를 포함
# ```

# %%
class Person:
    def __init__(self, name, gender):
        self.name = name   # 인스턴스 변수
        self.gender = gender
        print('Person 생성자 호출(객체 생성 == 클래스형 변수 생성 == 인스턴스 메모리 생성)')
    def __del__(self):
        print('Person 객체 소멸')
    def print_info(self):
        print(f"{self.name}님은 {self.gender}입니다")
    def __str__(self):
        return f"{self.name}님은 {self.gender}이죠"

# %%
p1 = Person('신사임당', '여자')
p1.print_info()
print(p1.__str__())
print(p1)
# Out:
# Person 생성자 호출(객체 생성 == 클래스형 변수 생성 == 인스턴스 메모리 생성)
# 신사임당님은 여자입니다
# 신사임당님은 여자이죠
# 신사임당님은 여자이죠

# %%
type(p1), isinstance(p1, Person)
# Out:
# (__main__.Person, True)

# %%
del p1
# Out:
# Person 객체 소멸

# %%
p2 = Person('홍길동', '남자')
p3 = p2
# Out:
# Person 생성자 호출(객체 생성 == 클래스형 변수 생성 == 인스턴스 메모리 생성)

# %%
del p2 # 레퍼런스 카운트가 0이 아님

# %%
del p3 # 레퍼런스 카운트가 0
# Out:
# Person 객체 소멸

# %% [markdown]
# **★ 생성자를 통한 멤버변수(인스턴스 변수)의 초기화 ★**
#
# **★ 파이썬은 함수를 중복정의(오버로딩) 불가 ★** <br>
# **★ 생성자 함수도 중복정의(오버로딩) 불가 ★**

# %%
# 일반함수의 중복정의 불가
def add(a, b):
    return a+b
def add(a, b, c): 
    return a+b+c
add(1, 2, 3)
# Out:
# 6

# %%
add(1, 2) # 에러남 - 밑에 걸로 덮어썼으니까

# %%
class Person:
    # 생성자를 이용한 인스턴스 변수 (멤버 변수) 초기화
#     def __init__(self):
#         self.name = "아무개"
#         self.gender = "남자"
#     def __init__(self, name):              
#         self.name = name
#         self.gender = "남자"

        # 생성자 함수 중복 정의 불가. 기본값을 갖는 매개변수를 이용해서 생성자 정의

    def __init__(self, name="아무개", gender="남자"):
        self.name = name
        self.gender = gender        
    def __str__(self):
        return f"{self.name}님은 {self.gender}네요"

# %%
p1 = Person()
p2 = Person("홍길동")
p3 = Person("신길숙", "여자")
print('p1 =', p1)
print('p2 =', p2)
print('p3 =', p3)
# Out:
# p1 = 아무개님은 남자네요
# p2 = 홍길동님은 남자네요
# p3 = 신길숙님은 여자네요

# %% [markdown]
# # 3절. 변수와 메소드
# - 인스턴스 변수(멤버변수) vs 클래스 변수 vs static 변수 (정적변수)
# - 인스턴스 메소드 (self) vs 클래스 메소드 (cls) vs static 메소드()

# %%
# 클래스 변수 : 클래스 내부에 선언 => 생성된 모든 인스턴스(객체)에 동일한 값을 가짐
# 클래스. 클래스 변수를 수정하면 모든 인스턴스에 반영될 수 있음
# 객체변수. 클래스변수를 수정하면 해당 객체에만 반영

class Person:  # 클래스 이름은 항상 대문자
    academy = 'MBC' # 클래스 변수
    def __init__(self, name="신길동", gender="남자"): 
        self.name = name # 인스턴스 변수
        self.gender = gender
        print('Person 객체 생성합니다')
    def __str__(self): 
        return "%s의 %s은(는) %s입니다" %(self.academy, self.name, self.gender)
print(Person)
print(Person.academy)
# Out:
# <class '__main__.Person'>
# MBC

# %%
p1 = Person()
p2 = Person()
# Out:
# Person 객체 생성합니다
# Person 객체 생성합니다

# %%
print(p1)
print(p2)
# Out:
# MBC의 신길동은(는) 남자입니다
# MBC의 신길동은(는) 남자입니다

# %%
Person.academy = "KBS"
print(p1)
print(p2)
p2.academy = "딴데"
p2.name = "홍길동"
print(p1)
print(p2)
# Out:
# KBS의 신길동은(는) 남자입니다
# KBS의 신길동은(는) 남자입니다
# KBS의 신길동은(는) 남자입니다
# 딴데의 홍길동은(는) 남자입니다
