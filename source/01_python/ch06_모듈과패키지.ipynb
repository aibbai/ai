# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:10pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:10pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %% [markdown]
# <font size='6' color="red">ch06. 모듈과 패키지</font>
#
# # 1절. 파이썬 표준 모듈 사용
# - 모듈 : 함수, 변수, 클래스 등을 담고 있는 파이썬 코드 파일(*.py)
# ```
# 파이썬 설치하는 방법
#     - python.org/microsoft store : 파이썬 표준모듈 200여개가 포함된 파이썬 인터프리터를 install(sys, re, datetime, time...)
#     - miniconda : python.org버전 보다 조금 많은 모듈이 포함된 인터프리터를 install
#     - anaconda : 몇백 개 이상의 패키지, 개발도구(IDE tool;jupyter notebook)를 포함한 인터프리터를 설치(200명이상의 기업체에서는 유료)
#     - uv(pip-파이썬 패키지 설치도구, 패키지/프로젝트 관리도구)를 이용한 설치
#         * 참조 : https://docs.astral.sh/uv/getting-started/installation/
#                 - powershell - ExecutionPolicy ByPass -c "irm https://astral.sh/uv/install.ps1 | iex" (powershell관리자 권한)
#         * uv설치 후 파이썬 설치 (반드시 powershell 관리자 권한으로 실행)
#
#         * Set-ExecutionPolicy RemoteSigned -Scope CurrentUser
#         * Get-ExecutionPolicy명령으로 RemoteSigned출력확인
#         * powershell -ExecutionPolicy ByPass -c "irm https://astral.sh/uv/install.ps1 | iex"
#         * powershell 닫았다 다시 열기
#         * uv python list
#         * uv python install 3.11(업계에서는 3.13이상은 잘 안 씀) - 지금은 하지 마셔요
# ```

# %%
# 1. import 모듈명 : 모듈안의 함수, 클래스, 변수를 모듈명.함수명()으로 사용
import time # time모듈 안의 함수, 변수, 클래스를 메모리 로드
time.ctime() # 현재 날짜와 시간
# Out:
# 'Mon Jul  6 10:50:43 2026'

# %%
time.time() # 1970.01.01 부터의 초
# Out:
# 1783303050.1997101

# %%
import time
start = time.time()
cnt = 0
while cnt<=10000000:
    cnt += 1
end = time.time()
print('반복문 1천만번 돈 시간 :', (end-start), '초')
# Out:
# 반복문 1천만번 돈 시간 : 0.9998044967651367 초

# %%
del time # time 모듈을 메모리에서 unload

# %%
# 2. from 모듈(A) import 함수|클래스|변수(B) - A 모듈안의 B만 로드
#    from 패키지(A) import 모듈 (B)        - A 패키지안의 B모듈을 로드
#    from 패키지(A).모듈명(B) import 함수명 (B) - A 패키지 안의 B모듈의 B함수만 로드
# from time import ctime
# from time import time
from time import ctime, time
ctime()
# Out:
# 'Mon Jul  6 11:08:02 2026'

# %%
time()
# Out:
# 1783303687.45928

# %%
del ctime
del time

# %%
# 3. import 모듈명 as 별칭 : 모듈을 메모리에 로드하고 별칭으로 사용
import time as t
t.ctime()
# Out:
# 'Mon Jul  6 11:10:29 2026'

# %%
t.time()
# Out:
# 1783303833.598499

# %%
time.time()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 time.time()
#
# NameError: name 'time' is not defined

# %%
del t

# %%
# 4. from 모듈명 import 함수명 as 별칭 : 모듈안의 함수를 메모리에 로드하고 별칭으로 함수를 사용
#    from 패키지명 imprt 모듈명 as 별칭 : 모듈명을 별칭으로 사용
#    from 패키지명.모듈명 import 함수명 as 별칭
from time import ctime as ct, time as ti
ct()
# Out:
# 'Mon Jul  6 11:14:05 2026'

# %%
import time
print(dir(time)) # time 모듈 안의 변수, 함수, 클래스명을 list로
# Out:
# ['_STRUCT_TM_ITEMS', '__doc__', '__loader__', '__name__', '__package__', '__spec__', 'altzone', 'asctime', 'ctime', 'daylight', 'get_clock_info', 'gmtime', 'localtime', 'mktime', 'monotonic', 'monotonic_ns', 'perf_counter', 'perf_counter_ns', 'process_time', 'process_time_ns', 'sleep', 'strftime', 'strptime', 'struct_time', 'thread_time', 'thread_time_ns', 'time', 'time_ns', 'timezone', 'tzname']

# %% [markdown]
# ```
# 모듈이나 모듈안의 함수를 가져오는 방법
#
# import A              - A 모듈을 가져옴
# import A as B         - A 모듈을 B 이름으로 가져옴
# from A import B       - A 모듈안의 B 함수(클래스|변수)를 가져옴
# from A import B as C  - A 모듈안의 B 함수를 C 이름으로 가져옴
#
# from A import B       - A 패키지 안의 B 모듈을 가져옴
# from A.B import C     - A 패키지 안의 B 모듈안의 C 함수 가져옴
# from A import B as C  - A 패키지 안의 B 모듈을 C 이름으로 가져옴
# from A.B import C as D - A 패키지 안의 B 모듈안의 C 를 D 이름으로 가져옴
# ```

# %% [markdown]
# # 2절. 사용자 정의 모듈
# - 함수나 클래스나 변수 등을 파이썬 파일(*.py)에 저장해서 모듈을 만들고, 재사용할 수 있음
# - 모듈을 가져오는 순서 (1)표준모듈 (2) sys.path변수에 저장된 경로

# %%
import add_operation
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 import add_operation
#
# ModuleNotFoundError: No module named 'add_operation'

# %%
import sys
sys.path
# Out:
# ['C:\\ai\\source\\01_python',
#  'C:\\Users\\Admin\\anaconda3\\python310.zip',
#  'C:\\Users\\Admin\\anaconda3\\DLLs',
#  'C:\\Users\\Admin\\anaconda3\\lib',
#  'C:\\Users\\Admin\\anaconda3',
#  '',
#  'C:\\Users\\Admin\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\Admin\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\Admin\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\Admin\\anaconda3\\lib\\site-packages\\Pythonwin']

# %%
r"C:\ai\source\pylib" == "C:\\ai\\source\\pylib"
# Out:
# True

# %%
sys.path.append(r"C:\ai\source\pylib")
sys.path
# Out:
# ['C:\\ai\\source\\01_python',
#  'C:\\Users\\Admin\\anaconda3\\python310.zip',
#  'C:\\Users\\Admin\\anaconda3\\DLLs',
#  'C:\\Users\\Admin\\anaconda3\\lib',
#  'C:\\Users\\Admin\\anaconda3',
#  '',
#  'C:\\Users\\Admin\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\Admin\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\Admin\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\Admin\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\ai\\source\\pylib',
#  'C:\\ai\\source\\pylib']

# %%
# 1. import 모듈명
import add_operation
add_operation.add_print(10)
# Out:
# 1부터 10까지 누적합은 55입니다

# %%
result = add_operation.add_return(10)
result
# Out:
# 55

# %%
add_operation.PI
# Out:
# 3.141592

# %%
# !python c:/ai/source/pylib/add_operation.py
# Out:
# ['c:/ai/source/pylib/add_operation.py']
# 기본적으로 실행시 숫자를 입력하지 않으면 100으로
# 1. add_print1부터 100까지 누적합은 5050입니다
# 2. add_return : 5050
# 3.141592

# %%
# !python c:/ai/source/pylib/add_operation.py 50
# Out:
# ['c:/ai/source/pylib/add_operation.py', '50']
# 1. add_print1부터 50까지 누적합은 1275입니다
# 2. add_return : 1275
# 3.141592

# %%
# 2. from A(모듈명) import B(함수명)
from add_operation import add_print, add_return, PI
PI
# Out:
# 3.141592

# %%
add_print(50)
# Out:
# 1부터 50까지 누적합은 1275입니다

# %%
# 3. import A as B
import add_operation as operation
operation.add_print(20)
# Out:
# 1부터 20까지 누적합은 210입니다

# %%
operation.PI
# Out:
# 3.141592

# %%
# 4. from A import B as C
from add_operation import add_print as add_p
add_p(20)
# Out:
# 1부터 20까지 누적합은 210입니다

# %%
PI
# Out:
# 3.141592

# %% [markdown]
# # 3절. 패키지
# ```
# - 모듈(py)들이 들어있는 폴더(__init__.py파일이 있어야)
# ```

# %%
sys.path
# Out:
# ['C:\\ai\\source\\01_python',
#  'C:\\Users\\Admin\\anaconda3\\python310.zip',
#  'C:\\Users\\Admin\\anaconda3\\DLLs',
#  'C:\\Users\\Admin\\anaconda3\\lib',
#  'C:\\Users\\Admin\\anaconda3',
#  '',
#  'C:\\Users\\Admin\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\Admin\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\Admin\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\Admin\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\ai\\source\\pylib',
#  'C:\\ai\\source\\pylib']

# %%
# 상위패키지를 import 한다고 하위패키지가 import 되지 않음
# 패키지를 import 한다고 모듈이 import 되지 않음
import sample_pac # sample_pac/__init__.py를 로드

# %%
sample_pac.test()
# Out:
# test해 봄

# %%
sample_pac.ab.a.hello()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 sample_pac.ab.a.hello()
#
# AttributeError: module 'sample_pac' has no attribute 'ab'

# %%
del sample_pac

# %%
import sample_pac.ab # ab/__init__.py가 로드
# Out:
# sample_pac안의 ab패키지 로드됨

# %%
sample_pac.ab.a.hello()

# %%
del sample_pac.ab

# %%
from sample_pac.ab import * # * : __all__=['a']을 로드

# %%
a.hello()
# Out:
# sample_pac/ab/a모듈의 hello

# %%
b.world()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 b.world()
#
# NameError: name 'b' is not defined

# %%
from sample_pac.ab import b
b.world()
# Out:
# sample_pac/ab/b 모듈안의 world

# %%
from sample_pac.ab.b import world
world()
# Out:
# sample_pac/ab/b 모듈안의 world

# %% [markdown]
# # 4절. 패키지 설치 및 삭제
# ```
# 아나콘다 프롬프트에서
# - 패키지 설치 : pip install 패키지명[==버전] / conda install 패키지명[==버전] / uv pip install 패키지명[==버전]
# - 패키지 확인 : pip show 패키지명           / conda list 패키지명
# - 패키지 삭제 : pip uninstall 패키지명      / conda remove 패키지명
# ```

# %%
import objgraph # 아나콘다 프롬프트에서 pip install objgraph==3.6.2

# %%
objgraph.show_most_common_types() # 메모리 사용량 출력
# Out:
# list          35681
# dict          34268
# function      18555
# Token         16825
# Operator      16358
# Name          13506
# tuple         13285
# PythonNode    11607
# ReferenceType 5580
# DFAPlan       5418

# %%
# !pip uninstall objgraph -y
# Out:
# Found existing installation: objgraph 3.6.2
# Uninstalling objgraph-3.6.2:
#   Successfully uninstalled objgraph-3.6.2

# %% [markdown]
# # 5절. 연습문제

# %%
1. 3번

# %%
2. 4번 
# from time import ctime as ct
# ct()

# %%
3. __init__.py

# %%
4. __all__

# %%
5. 1번
